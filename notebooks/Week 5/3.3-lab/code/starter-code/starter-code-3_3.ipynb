# %% [markdown]
# # Local Postgresql Database Lab
#
# In this lab we will practice adding and removing data from a local Postgresql database. We will:
#
# - Walk through instructions on how to set up and configure a local postgresql server
# - Create a database and a table using SQL and CRUD data in/from that table.
# - Learn how to copy data from a CSV file into this local database
# - Practice our SQL with a practice assignment.

# %% [markdown]
# ## 1. Install PostgreSQL locally
#
# You should have already taken care of this in the Installfest, but just in case, [here](http://www.postgresql.org/download/) are the instructions for the most common platforms.

# %% [markdown]
# ## 2. Launch and connect to a local PostgreSQL server
#
# Now that you've installed PostgreSQL locally, practice connecting with the following methods:
# - Command-line (psql)
# - Sqlalchemy + Pandas
# - Ipython-notebook using the ipython-sql extension
#
# **Check:** List the existing databases, there should be none, right?
# > not true, there are some default databases from postgres
#
# **Check:** If there are databases, check the tables' contents. Hint: information_schema.tables

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('postgresql://localhost:5432/allenbyron')
pd.read_sql('select * from information_schema.tables;', engine)
# Out:
#     table_catalog        table_schema                       table_name  \
# 0      allenbyron              public                             test
# 1      allenbyron          pg_catalog                     pg_statistic
# 2      allenbyron          pg_catalog                          pg_type
# 3      allenbyron              public                      globalgoals
# 4      allenbyron          pg_catalog                        pg_authid
# 5      allenbyron          pg_catalog                         pg_roles
# 6      allenbyron          pg_catalog                        pg_shadow
# 7      allenbyron          pg_catalog                         pg_group
# 8      allenbyron          pg_catalog                          pg_user
# 9      allenbyron          pg_catalog                      pg_policies
# 10     allenbyron          pg_catalog                      pg_settings
# 11     allenbyron          pg_catalog                         pg_rules
# 12     allenbyron          pg_catalog                 pg_file_settings
# 13     allenbyron          pg_catalog                         pg_views
# 14     allenbyron          pg_catalog                        pg_tables
# 15     allenbyron          pg_catalog                      pg_matviews
# 16     allenbyron          pg_catalog                       pg_indexes
# 17     allenbyron          pg_catalog                         pg_stats
# 18     allenbyron          pg_catalog                         pg_locks
# 19     allenbyron          pg_catalog                       pg_cursors
# 20     allenbyron          pg_catalog          pg_available_extensions
# 21     allenbyron          pg_catalog  pg_available_extension_versions
# 22     allenbyron          pg_catalog                pg_prepared_xacts
# 23     allenbyron          pg_catalog           pg_prepared_statements
# 24     allenbyron          pg_catalog                     pg_seclabels
# 25     allenbyron          pg_catalog              pg_timezone_abbrevs
# 26     allenbyron          pg_catalog                pg_timezone_names
# 27     allenbyron          pg_catalog               pg_stat_all_tables
# 28     allenbyron          pg_catalog          pg_stat_xact_all_tables
# 29     allenbyron          pg_catalog               pg_stat_sys_tables
# ..            ...                 ...                              ...
# 148    allenbyron  information_schema                role_table_grants
# 149    allenbyron  information_schema                           tables
# 150    allenbyron  information_schema                       transforms
# 151    allenbyron  information_schema         triggered_update_columns
# 152    allenbyron  information_schema                         triggers
# 153    allenbyron  information_schema                   udt_privileges
# 154    allenbyron  information_schema                  role_udt_grants
# 155    allenbyron  information_schema                 usage_privileges
# 156    allenbyron  information_schema                role_usage_grants
# 157    allenbyron  information_schema               user_defined_types
# 158    allenbyron  information_schema                view_column_usage
# 159    allenbyron  information_schema               view_routine_usage
# 160    allenbyron  information_schema                 view_table_usage
# 161    allenbyron  information_schema                            views
# 162    allenbyron  information_schema             data_type_privileges
# 163    allenbyron  information_schema                    element_types
# 164    allenbyron  information_schema        _pg_foreign_table_columns
# 165    allenbyron  information_schema                   column_options
# 166    allenbyron  information_schema        _pg_foreign_data_wrappers
# 167    allenbyron  information_schema     foreign_data_wrapper_options
# 168    allenbyron  information_schema            foreign_data_wrappers
# 169    allenbyron  information_schema              _pg_foreign_servers
# 170    allenbyron  information_schema           foreign_server_options
# 171    allenbyron  information_schema                  foreign_servers
# 172    allenbyron  information_schema               _pg_foreign_tables
# 173    allenbyron  information_schema            foreign_table_options
# 174    allenbyron  information_schema                   foreign_tables
# 175    allenbyron  information_schema                _pg_user_mappings
# 176    allenbyron  information_schema             user_mapping_options
# 177    allenbyron  information_schema                    user_mappings
#
#      table_type self_referencing_column_name reference_generation  \
# 0    BASE TABLE                         None                 None
# 1    BASE TABLE                         None                 None
# 2    BASE TABLE                         None                 None
# 3    BASE TABLE                         None                 None
# 4    BASE TABLE                         None                 None
# 5          VIEW                         None                 None
# 6          VIEW                         None                 None
# 7          VIEW                         None                 None
# 8          VIEW                         None                 None
# 9          VIEW                         None                 None
# 10         VIEW                         None                 None
# 11         VIEW                         None                 None
# 12         VIEW                         None                 None
# 13         VIEW                         None                 None
# 14         VIEW                         None                 None
# 15         VIEW                         None                 None
# 16         VIEW                         None                 None
# 17         VIEW                         None                 None
# 18         VIEW                         None                 None
# 19         VIEW                         None                 None
# 20         VIEW                         None                 None
# 21         VIEW                         None                 None
# 22         VIEW                         None                 None
# 23         VIEW                         None                 None
# 24         VIEW                         None                 None
# 25         VIEW                         None                 None
# 26         VIEW                         None                 None
# 27         VIEW                         None                 None
# 28         VIEW                         None                 None
# 29         VIEW                         None                 None
# ..          ...                          ...                  ...
# 148        VIEW                         None                 None
# 149        VIEW                         None                 None
# 150        VIEW                         None                 None
# 151        VIEW                         None                 None
# 152        VIEW                         None                 None
# 153        VIEW                         None                 None
# 154        VIEW                         None                 None
# 155        VIEW                         None                 None
# 156        VIEW                         None                 None
# 157        VIEW                         None                 None
# 158        VIEW                         None                 None
# 159        VIEW                         None                 None
# 160        VIEW                         None                 None
# 161        VIEW                         None                 None
# 162        VIEW                         None                 None
# 163        VIEW                         None                 None
# 164        VIEW                         None                 None
# 165        VIEW                         None                 None
# 166        VIEW                         None                 None
# 167        VIEW                         None                 None
# 168        VIEW                         None                 None
# 169        VIEW                         None                 None
# 170        VIEW                         None                 None
# 171        VIEW                         None                 None
# 172        VIEW                         None                 None
# 173        VIEW                         None                 None
# 174        VIEW                         None                 None
# 175        VIEW                         None                 None
# 176        VIEW                         None                 None
# 177        VIEW                         None                 None
#
#     user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                        None                     None                   None
# 1                        None                     None                   None
# 2                        None                     None                   None
# 3                        None                     None                   None
# 4                        None                     None                   None
# 5                        None                     None                   None
# 6                        None                     None                   None
# 7                        None                     None                   None
# 8                        None                     None                   None
# 9                        None                     None                   None
# 10                       None                     None                   None
# 11                       None                     None                   None
# 12                       None                     None                   None
# 13                       None                     None                   None
# 14                       None                     None                   None
# 15                       None                     None                   None
# 16                       None                     None                   None
# 17                       None                     None                   None
# 18                       None                     None                   None
# 19                       None                     None                   None
# 20                       None                     None                   None
# 21                       None                     None                   None
# 22                       None                     None                   None
# 23                       None                     None                   None
# 24                       None                     None                   None
# 25                       None                     None                   None
# 26                       None                     None                   None
# 27                       None                     None                   None
# 28                       None                     None                   None
# 29                       None                     None                   None
# ..                        ...                      ...                    ...
# 148                      None                     None                   None
# 149                      None                     None                   None
# 150                      None                     None                   None
# 151                      None                     None                   None
# 152                      None                     None                   None
# 153                      None                     None                   None
# 154                      None                     None                   None
# 155                      None                     None                   None
# 156                      None                     None                   None
# 157                      None                     None                   None
# 158                      None                     None                   None
# 159                      None                     None                   None
# 160                      None                     None                   None
# 161                      None                     None                   None
# 162                      None                     None                   None
# 163                      None                     None                   None
# 164                      None                     None                   None
# 165                      None                     None                   None
# 166                      None                     None                   None
# 167                      None                     None                   None
# 168                      None                     None                   None
# 169                      None                     None                   None
# 170                      None                     None                   None
# 171                      None                     None                   None
# 172                      None                     None                   None
# 173                      None                     None                   None
# 174                      None                     None                   None
# 175                      None                     None                   None
# 176                      None                     None                   None
# 177                      None                     None                   None
#
#     is_insertable_into is_typed commit_action
# 0                  YES       NO          None
# 1                  YES       NO          None
# 2                  YES       NO          None
# 3                  YES       NO          None
# 4                  YES       NO          None
# 5                   NO       NO          None
# 6                   NO       NO          None
# 7                  YES       NO          None
# 8                   NO       NO          None
# 9                   NO       NO          None
# 10                  NO       NO          None
# 11                  NO       NO          None
# 12                  NO       NO          None
# 13                  NO       NO          None
# 14                  NO       NO          None
# 15                  NO       NO          None
# 16                  NO       NO          None
# 17                  NO       NO          None
# 18                  NO       NO          None
# 19                  NO       NO          None
# 20                  NO       NO          None
# 21                  NO       NO          None
# 22                  NO       NO          None
# 23                  NO       NO          None
# 24                  NO       NO          None
# 25                  NO       NO          None
# 26                  NO       NO          None
# 27                  NO       NO          None
# 28                  NO       NO          None
# 29                  NO       NO          None
# ..                 ...      ...           ...
# 148                 NO       NO          None
# 149                 NO       NO          None
# 150                 NO       NO          None
# 151                 NO       NO          None
# 152                 NO       NO          None
# 153                 NO       NO          None
# 154                 NO       NO          None
# 155                 NO       NO          None
# 156                 NO       NO          None
# 157                 NO       NO          None
# 158                 NO       NO          None
# 159                 NO       NO          None
# 160                 NO       NO          None
# 161                 NO       NO          None
# 162                 NO       NO          None
# 163                 NO       NO          None
# 164                 NO       NO          None
# 165                 NO       NO          None
# 166                 NO       NO          None
# 167                 NO       NO          None
# 168                 NO       NO          None
# 169                 NO       NO          None
# 170                 NO       NO          None
# 171                 NO       NO          None
# 172                 NO       NO          None
# 173                 NO       NO          None
# 174                 NO       NO          None
# 175                 NO       NO          None
# 176                 NO       NO          None
# 177                 NO       NO          None
#
# [178 rows x 12 columns]

# %% [markdown]
# ## 3. Create DB
# Once you are connected to your local Postgresql server, create a new database. Call it `lab33`.
#
# Practice creating and deleting the database with the following methods:
# - Command-line:
# >     CREATE database lab33;
# >     DROP database lab33;
#
# - Sqlalchemy
# - Ipython-notebook using the ipython-sql extension

# %% [markdown]
# ## 4. CRUD (Create, Read, Update, and Delete)
#
# In lesson 1.1 you learned how to add and remove data from sqlite. Let's review that on our local PostgreSQL installation.

# %% [markdown]
# ### 4.a: Creating Tables and Adding Columns
#
# 1. Create an table called `table1` with a single column `field1` containing an INTEGER PRIMARY KEY. Practice doing this with any of the methods above.
# - Add a few more columns to `table1`:
#     - field2 VARCHAR(16)
#     - field3 REAL
#     - field4 TEXT
# check [the doc](http://www.postgresql.org/docs/9.3/static/datatype.html) for more info on data types supported by postgresql.
# - Check tables and schemas using command line or postico

# %% [markdown]
# ### 4.b: Add Data
#
# Add some data to `table1`:
#
# |field1|field2|field3|field4|
# |----|
# |1|'Henry James'|42|'75 Mission Street, San Francisco, CA'|
# |2|'Carol James'|40|'75 Mission Street, San Francisco, CA'|
# |3|'Jesse James'|12|'75 Mission Street, San Francisco, CA'|

# %% [markdown]
# ### 4.c: Read Data
# Read the content of the table,

# %% [markdown]
# ### 4.d: Update Records
# Suppose we need to update an existing record with new data - e.g. maybe `Jesse James` is only 9. Use the update command to do this.

# %% [markdown]
# ### 4.e: Remove Records
# To remove records use the DELETE command. Delete the entry for anyone matching `Jesse`.

# %% [markdown]
# ## 5. Data from CSV
#
# Copy CSV data from a local file into a local PostgreSQL database. We will use a [dataset](../../assets/datasets/Eviction_Notices.csv) pulled from the SF open data website. It contains a set of eviction notices issued in San Francisco.
#
# Open the data in a text editor and have a look at it.

# %% [markdown]
# ### 5.a: Simple Import
#
# Read [this post](http://stackoverflow.com/questions/2987433/how-to-import-csv-file-data-into-a-postgresql-table) to learn how you can import data from CSV to PostgreSQL.
#
# Notice that you have to decide the type for each column. Let's keep it simple and import everything as a string of text for now.
#
# - Create a table called `evictions_simple` and import the data as varchar.
# - Check that everything worked fine by loading a few lines from the table.
# - Try some simple queries:
#     - count how many evictions are due to non_payments
#     - list the 3 most recent evictions
#
#
# **Hint:** A good practice when you create a new table is to always drop it first, in case it already exists.
#
# **Check:** Did you avoid importing the header as a record?

# %% [markdown]
# ### 5.b: Data Cleaning and Import
#
# If you've executed the last query correctly (most recent evictions), you'll have noticed that the dates are not correctly understood. This is because we were sloppy and imported the data as string for all fields.
#
# Let's see what data types we would ideally like to have for each column.
#
# [Here are data types](http://www.tutorialspoint.com/postgresql/postgresql_data_types.htm)
#
# - Discuss in pairs each column and then let's summarize together. Which data type would you choose for each field?
# - Repeat the import to a new table called `evictions`. Notice that line 31494 may throw an error. Why is that?
# > There are two ` characters that do not belong.
# - Repeat the query for the 3 most recent evictions. Does it work now?

# %% [markdown]
# ## 6. Queries
#
# Now that we have imported the data with correct data types, let's query the `evictions` table and find out a few things about SF and evictions.
#
# Questions:
# - How many neighborhoods are there in SF? List them alphabetically
# - How many supervisor districts?
# - How many unique zip codes?
#     - Are there any bad data in these? how many?
# - What are the top 5 causes of eviction?

# %% [markdown]
# ### 6.a: How many neighborhoods are there in SF? List them alphabetically.

# %% [markdown]
# ### 6.b: How many supervisor districts?

# %% [markdown]
# ### 6.c how many unique zip codes?
#
# Are there any bad data in these?

# %% [markdown]
# ### 6.d: What are the top 5 causes of eviction?
#
# You may find it easier to answer this question using pandas.

# %% [markdown]
# ## Bonus
# - Let's count the number of evictions for each year
#     - How has the number varied?
#     - Can you compare this with the nasdaq index? (use the DataReader module in Pandas to get the data)
