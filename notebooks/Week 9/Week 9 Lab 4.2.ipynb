# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('../../notebooks/Week 9/4.2-lab/assets/datasets/h02.csv')
df.columns = ['Date','Sale']
df = df.set_index(['Date'])
df.index = df.index.to_datetime()
# Out:
# /Users/allenbyron/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: to_datetime is deprecated. Use pd.to_datetime(...)

# %%
df.head()
# Out:
#                 Sale
# 1991-08-02  0.400906
# 1991-09-02  0.432159
# 1991-10-02  0.492543
# 1991-11-02  0.502369
# 1991-12-02  0.602652

# %%
df.stack().plot()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
diff0 = df.stack().diff(periods=12)[12:]
diff0.plot(title='Sales')

# %%
plot_acf(diff0, lags=12)
plot_pacf(diff0, lags=12)

# %%
diff1 = diff0.diff()[1:]
diff1.plot(title='Sales')

# %%
plot_acf(diff1, lags=30)
plot_pacf(diff1, lags=30)

# %%
import statsmodels.api as sm
data = df.stack().values
model = sm.tsa.statespace.SARIMAX(data, order=(0,1,1), seasonal_order=(0,1,1,4))
results = model.fit()
print results.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-fa9a3adeb52c> in <module>()
#       1 import statsmodels.api as sm
#       2 data = df.stack().values
# ----> 3 model = sm.tsa.statespace.SARIMAX(data, order=(0,1,1), seasonal_order=(0,1,1,4))
#       4 results = model.fit()
#       5 print results.summary()
#
# AttributeError: 'module' object has no attribute 'statespace'
