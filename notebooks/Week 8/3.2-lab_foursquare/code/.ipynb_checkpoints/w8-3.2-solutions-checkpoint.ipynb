# %% [markdown]
# # Setting up Foursquare data for analysis

# %% [markdown]
# Today's lab is going to get your hands dirty with respect to the Foursquare API. We're also going to build a simple crawler/scraper that will go through the JSON hierarchy, extract the data we want, and deposit them into a Pandas table so we can do simple analysis.
#
# Just in case you're unfamiliar with this concept, please refer to the Wikipedia page (it's actually pretty good): https://en.wikipedia.org/wiki/Web_scraping, and maybe spend a few moments discussing the concepts and how it could help you in the future as a data scientist to have this "hackish" skill.

# %% [markdown]
# Setup your access token to foursquare

# %%
# Solutions

import foursquare
import json
import pandas as pd
import unicodedata


#ACCESS_TOKEN = ""
#client = foursquare.Foursquare(access_token=ACCESS_TOKEN)

CLIENT_ID = 'YOUR_CLIENT_ID'
CLIENT_SECRET = 'YOUR_CLIENT_SECRET'
client = foursquare.Foursquare(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %% [markdown]
# Use a foursquare python library method to search for suitable venues around a city near you. Print the associated JSON output in a nice way with appropriate spacing and indentation

# %%
# Solution

starting_list = client.venues.search(params={'near': 'Sydney, NSW', 'radius':'1500'})
print(starting_list)
# Out:
# {u'confident': True, u'geocode': {u'parents': [], u'what': u'', u'where': u'sydney nsw', u'feature': {u'highlightedName': u'<b>Sydney</b>, <b>NSW</b>, Australia', u'displayName': u'Sydney, NSW, Australia', u'name': u'Sydney', u'longId': u'72057594040075650', u'cc': u'AU', u'id': u'geonameid:2147714', u'geometry': {u'center': {u'lat': -33.86785, u'lng': 151.20732}, u'bounds': {u'sw': {u'lat': -34.18942992635369, u'lng': 150.58820004399706}, u'ne': {u'lat': -33.37850601479644, u'lng': 151.34320099544556}}}, u'matchedName': u'Sydney, NSW, Australia', u'woeType': 7, u'slug': u'sydney'}}, u'venues': [{u'verified': True, u'name': u'The Westin Sydney', u'referralId': u'v-1477449429', u'venueChains': [], u'url': u'http://westinsydney.com', u'storeId': u'1183', u'hereNow': {u'count': 0, u'groups': [], u'summary': u'Nobody here'}, u'specials': {u'count': 0, u'items': []}, u'allowMenuUrlEdit': True, u'contact': {u'facebookName': u'The Westin Sydney', u'twitter': u'westin', u'phone': u'+61282231111', u'facebook': u'168294463192331', u'formattedPhone': u'+61 2 8223 1111', u'facebookUsername': u'westinsydney'}, u'hasPerk': False, u'location': {u'city': u'Sydney', u'labeledLatLngs': [{u'lat': -33.86762491432675, u'lng': 151.20745239541233, u'label': u'display'}], u'cc': u'AU', u'country': u'Australia', u'postalCode': u'2000', u'state': u'NSW', u'formattedAddress': [u'1 Martin Pl (at George St.)', u'Sydney NSW 2000', u'Australia'], u'crossStreet': u'at George St.', u'address': u'1 Martin Pl', u'lat': -33.86762491432675, u'lng': 151.20745239541233}, u'beenHere': {u'unconfirmedCount': 0, u'marked': False, u'lastCheckinExpiredAt': 0}, u'stats': {u'tipCount': 77, u'checkinsCount': 9514, u'usersCount': 3688}, u'id': u'4b05875bf964a520428d22e3', u'categories': [{u'pluralName': u'Hotels', u'primary': True, u'name': u'Hotel', u'shortName': u'Hotel', u'id': u'4bf58dd8d48988d1fa931735', u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', u'suffix': u'.png'}}]}, {u'verified': False, u'name': u'Sydney', u'referralId': u'v-1477449429', u'url': u'http://www.cityofsydney.nsw.gov.au', u'hereNow': {u'count': 4, u'groups': [{u'count': 4, u'items': [], u'type': u'others', u'name': u'Other people here'}], u'summary': u'4 people are here'}, u'specials': {u'count': 0, u'items': []}, u'venueChains': [], u'contact': {u'twitter': u'cityofsydney'}, u'hasPerk': False, u'location': {u'cc': u'AU', u'country': u'Australia', u'postalCode': u'2000', u'state': u'New South Wales', u'formattedAddress': [u'NSW 2000', u'Australia'], u'lat': -33.86849676207976, u'lng': 151.20740117073615}, u'beenHere': {u'unconfirmedCount': 0, u'marked': False, u'lastCheckinExpiredAt': 0}, u'stats': {u'tipCount': 26, u'checkinsCount': 50110, u'usersCount': 11206}, u'id': u'5081ca91e4b0607ce86717c3', u'categories': [{u'pluralName': u'Cities', u'primary': True, u'name': u'City', u'shortName': u'City', u'id': u'50aa9e094b90af0d42d5de0d', u'icon': {u'prefix': u'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_', u'suffix': u'.png'}}]}, {u'verified': False, u'name': u'Martin Place', u'referralId': u'v-1477449429', u'venueChains': [], u'hereNow': {u'count': 1, u'groups': [{u'count': 1, u'items': [], u'type': u'others', u'name': u'Other people here'}], u'summary': u'One other person is here'}, u'specials': {u'count': 0, u'items': []}, u'contact': {}, u'hasPerk': False, u'location': {u'city': u'Sydney', u'labeledLatLngs': [{u'lat': -33.86764061576283, u'lng': 151.20928645133972, u'label': u'display'}], u'cc': u'AU', u'country': u'Australia', u'postalCode': u'2000', u'state': u'NSW', u'formattedAddress': [u'Martin Pl.', u'Sydney NSW 2000', u'Australia'], u'address': u'Martin Pl.', u'lat': -33.86764061576283, u'lng': 151.20928645133972}, u'beenHere': {u'unconfirmedCount': 0, u'marked': False, u'lastCheckinExpiredAt': 0}, u'stats': {u'tipCount': 30, u'checkinsCount': 14790, u'usersCount': 4568}, u'id': u'4b0cf428f964a520cc4223e3', u'categories': [{u'pluralName': u ...

# %% [markdown]
# Wow... that should look like a total mess to you. Read the following docs: https://docs.python.org/2/library/json.html, and read the part about pretty printing. Once you think you've understood the method, deploy it here and see the world a difference a bit of spacing and indenting makes!

# %%
print(json.dumps(starting_list, indent = 4))
# Out:
# {
#     "confident": true,
#     "geocode": {
#         "parents": [],
#         "what": "",
#         "where": "sydney nsw",
#         "feature": {
#             "highlightedName": "<b>Sydney</b>, <b>NSW</b>, Australia",
#             "displayName": "Sydney, NSW, Australia",
#             "name": "Sydney",
#             "longId": "72057594040075650",
#             "cc": "AU",
#             "id": "geonameid:2147714",
#             "geometry": {
#                 "center": {
#                     "lat": -33.86785,
#                     "lng": 151.20732
#                 },
#                 "bounds": {
#                     "sw": {
#                         "lat": -34.18942992635369,
#                         "lng": 150.58820004399706
#                     },
#                     "ne": {
#                         "lat": -33.37850601479644,
#                         "lng": 151.34320099544556
#                     }
#                 }
#             },
#             "matchedName": "Sydney, NSW, Australia",
#             "woeType": 7,
#             "slug": "sydney"
#         }
#     },
#     "venues": [
#         {
#             "verified": true,
#             "name": "The Westin Sydney",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "url": "http://westinsydney.com",
#             "storeId": "1183",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "facebookName": "The Westin Sydney",
#                 "twitter": "westin",
#                 "phone": "+61282231111",
#                 "facebook": "168294463192331",
#                 "formattedPhone": "+61 2 8223 1111",
#                 "facebookUsername": "westinsydney"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86762491432675,
#                         "lng": 151.20745239541233,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1 Martin Pl (at George St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "at George St.",
#                 "address": "1 Martin Pl",
#                 "lat": -33.86762491432675,
#                 "lng": 151.20745239541233
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 77,
#                 "checkinsCount": 9514,
#                 "usersCount": 3688
#             },
#             "id": "4b05875bf964a520428d22e3",
#             "categories": [
#                 {
#                     "pluralName": "Hotels",
#                     "primary": true,
#                     "name": "Hotel",
#                     "shortName": "Hotel",
#                     "id": "4bf58dd8d48988d1fa931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Sydney",
#             "referralId": "v-1477449429",
#             "url": "http://www.cityofsydney.nsw.gov.au",
#             "hereNow": {
#                 "count": 4,
#                 "groups": [
#                     {
#                         "count": 4,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "4 people are here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {
#                 "twitter": "cityofsydney"
#             },
#             "hasPerk": false,
#             "location": {
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "New South Wales",
#                 "formattedAddress": [
#                     "NSW 2000",
#                     "Australia"
#                 ],
#                 "lat": -33.86849676207976,
#                 "lng": 151.20740117073615
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 26,
#                 "checkinsCount": 50110,
#                 "usersCount": 11206
#             },
#             "id": "5081ca91e4b0607ce86717c3",
#             "categories": [
#                 {
#                     "pluralName": "Cities",
#                     "primary": true,
#                     "name": "City",
#                     "shortName": "City",
#                     "id": "50aa9e094b90af0d42d5de0d",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Martin Place",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86764061576283,
#                         "lng": 151.20928645133972,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "Martin Pl.",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "Martin Pl.",
#                 "lat": -33.86764061576283,
#                 "lng": 151.20928645133972
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 30,
#                 "checkinsCount": 14790,
#                 "usersCount": 4568
#             },
#             "id": "4b0cf428f964a520cc4223e3",
#             "categories": [
#                 {
#                     "pluralName": "Plazas",
#                     "primary": true,
#                     "name": "Plaza",
#                     "shortName": "Plaza",
#                     "id": "4bf58dd8d48988d164941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Westin Executive Club",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61282231111",
#                 "formattedPhone": "+61 2 8223 1111"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.867860609530204,
#                         "lng": 151.2075889946297,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "Level 28, 1 Martin Pl. (Pitt St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "Pitt St.",
#                 "address": "Level 28, 1 Martin Pl.",
#                 "lat": -33.867860609530204,
#                 "lng": 151.2075889946297
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 3,
#                 "checkinsCount": 560,
#                 "usersCount": 189
#             },
#             "id": "4cfd5b1134c1a0939ae64f0e",
#             "categories": [
#                 {
#                     "pluralName": "Hotel Bars",
#                     "primary": true,
#                     "name": "Hotel Bar",
#                     "shortName": "Hotel Bar",
#                     "id": "4bf58dd8d48988d1d5941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Atlassian",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "twitter": "atlassian"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86718182966821,
#                         "lng": 151.20693683624268,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "Level 6, 341 George St. (Wynyard St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "Wynyard St.",
#                 "address": "Level 6, 341 George St.",
#                 "lat": -33.86718182966821,
#                 "lng": 151.20693683624268
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 13,
#                 "checkinsCount": 5450,
#                 "usersCount": 684
#             },
#             "id": "4b05d0adf964a520cee322e3",
#             "categories": [
#                 {
#                     "pluralName": "Tech Startups",
#                     "primary": true,
#                     "name": "Tech Startup",
#                     "shortName": "Tech Startup",
#                     "id": "4bf58dd8d48988d125941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/technology_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Wynyard Station (Platforms 3 & 4)",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "phone": "+61292242959",
#                 "twitter": "131500trains",
#                 "formattedPhone": "+61 2 9224 2959"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86566522674262,
#                         "lng": 151.2064848209958,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "George St. (Underground)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "Underground",
#                 "address": "George St.",
#                 "lat": -33.86566522674262,
#                 "lng": 151.2064848209958
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 18,
#                 "checkinsCount": 11257,
#                 "usersCount": 2219
#             },
#             "id": "4cda164799026dcb1d160481",
#             "categories": [
#                 {
#                     "pluralName": "Platforms",
#                     "primary": true,
#                     "name": "Platform",
#                     "shortName": "Platform",
#                     "id": "4f4531504b9074f6e4fb0102",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/trainstation_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Fitness First",
#             "referralId": "v-1477449429",
#             "venueChains": [
#                 {
#                     "id": "556f4530bd6a007c7738e4d8"
#                 }
#             ],
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61292253900",
#                 "formattedPhone": "+61 2 9225 3900"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86872775673394,
#                         "lng": 151.20805570951154,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "175 Pitt St (at King St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "at King St.",
#                 "address": "175 Pitt St",
#                 "lat": -33.86872775673394,
#                 "lng": 151.20805570951154
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 7,
#                 "checkinsCount": 1939,
#                 "usersCount": 245
#             },
#             "id": "4b5518a8f964a5200edb27e3",
#             "categories": [
#                 {
#                     "pluralName": "Gyms",
#                     "primary": true,
#                     "name": "Gym",
#                     "shortName": "Gym",
#                     "id": "4bf58dd8d48988d176941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/gym_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Australia Post - Sydney GPO Post Shop",
#             "referralId": "v-1477449429",
#             "url": "http://auspost.com.au",
#             "storeId": "270940",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [
#                 {
#                     "id": "556e40c7bd6a82902e2671c5"
#                 }
#             ],
#             "contact": {
#                 "facebookName": "Australia Post",
#                 "twitter": "auspost",
#                 "phone": "+61131318",
#                 "facebook": "96085205666",
#                 "formattedPhone": "+61 13 13 18",
#                 "facebookUsername": "australiapost"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86753722792263,
#                         "lng": 151.20716781408782,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1 Martin Pl. (George St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "George St.",
#                 "address": "1 Martin Pl.",
#                 "lat": -33.86753722792263,
#                 "lng": 151.20716781408782
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 3,
#                 "checkinsCount": 1526,
#                 "usersCount": 514
#             },
#             "id": "4b1c75f4f964a520960724e3",
#             "categories": [
#                 {
#                     "pluralName": "Post Offices",
#                     "primary": true,
#                     "name": "Post Office",
#                     "shortName": "Post Office",
#                     "id": "4bf58dd8d48988d172941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/postoffice_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Fruit Stall",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86886189709453,
#                         "lng": 151.2073954791065,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "Barrack St. (at George St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "at George St.",
#                 "address": "Barrack St.",
#                 "lat": -33.86886189709453,
#                 "lng": 151.2073954791065
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 469,
#                 "usersCount": 57
#             },
#             "id": "4cbb648c0180721edc4e9f61",
#             "categories": [
#                 {
#                     "pluralName": "Food Trucks",
#                     "primary": true,
#                     "name": "Food Truck",
#                     "shortName": "Food Truck",
#                     "id": "4bf58dd8d48988d1cb941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/streetfood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "1 Martin Place",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86759830064373,
#                         "lng": 151.20723724365234,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1 Martin Pl.",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "1 Martin Pl.",
#                 "lat": -33.86759830064373,
#                 "lng": 151.20723724365234
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 612,
#                 "usersCount": 311
#             },
#             "id": "4db74a218154d78113bdf29c",
#             "categories": [
#                 {
#                     "pluralName": "Buildings",
#                     "primary": true,
#                     "name": "Building",
#                     "shortName": "Building",
#                     "id": "4bf58dd8d48988d130941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Bankwest",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "url": "http://bankwest.com.au",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61131719",
#                 "twitter": "bankwest",
#                 "formattedPhone": "+61 13 17 19"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.867733565321466,
#                         "lng": 151.20709951464605,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "3/345 George St.",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "3/345 George St.",
#                 "lat": -33.867733565321466,
#                 "lng": 151.20709951464605
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 127,
#                 "usersCount": 74
#             },
#             "id": "4b6f8116f964a5205df32ce3",
#             "categories": [
#                 {
#                     "pluralName": "Banks",
#                     "primary": true,
#                     "name": "Bank",
#                     "shortName": "Bank",
#                     "id": "4bf58dd8d48988d10a951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/financial_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Palomino Espresso",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61414857818",
#                 "facebookUsername": "PalominoEspresso",
#                 "facebook": "403010193060021",
#                 "formattedPhone": "+61 414 857 818",
#                 "facebookName": "Palomino Espresso"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86732720737688,
#                         "lng": 151.20601241916407,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1/61 York St.",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "1/61 York St.",
#                 "lat": -33.86732720737688,
#                 "lng": 151.20601241916407
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 23,
#                 "checkinsCount": 2161,
#                 "usersCount": 441
#             },
#             "id": "4fd7d6a9e4b0f564e740f7c2",
#             "categories": [
#                 {
#                     "pluralName": "Caf\u00e9s",
#                     "primary": true,
#                     "name": "Caf\u00e9",
#                     "shortName": "Caf\u00e9",
#                     "id": "4bf58dd8d48988d16d941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/cafe_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Burberry",
#             "referralId": "v-1477449429",
#             "venueChains": [
#                 {
#                     "id": "556c9585a7c8a11a36bdbd78"
#                 }
#             ],
#             "url": "http://www.Burberry.com",
#             "storeId": "0621",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "facebookName": "Burberry",
#                 "twitter": "burberry",
#                 "phone": "+61282968588",
#                 "facebook": "122792026424",
#                 "formattedPhone": "+61 2 8296 8588",
#                 "facebookUsername": "Burberry"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86761529600227,
#                         "lng": 151.2069913739235,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "George St. (at Barrack St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "at Barrack St.",
#                 "address": "George St.",
#                 "lat": -33.86761529600227,
#                 "lng": 151.2069913739235
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 4,
#                 "checkinsCount": 797,
#                 "usersCount": 482
#             },
#             "id": "4c48b3726f1420a1c510a354",
#             "categories": [
#                 {
#                     "pluralName": "Boutiques",
#                     "primary": true,
#                     "name": "Boutique",
#                     "shortName": "Boutique",
#                     "id": "4bf58dd8d48988d104951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "The Cenotaph",
#             "referralId": "v-1477449429",
#             "url": "http://www.warmemorialsnsw.asn.au",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86756489395594,
#                         "lng": 151.20770931243896,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "Martin Pl. (Pitt St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "Pitt St.",
#                 "address": "Martin Pl.",
#                 "lat": -33.86756489395594,
#                 "lng": 151.20770931243896
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 1031,
#                 "usersCount": 278
#             },
#             "id": "4df98be018381da9362a1cd1",
#             "categories": [
#                 {
#                     "pluralName": "Monuments / Landmarks",
#                     "primary": true,
#                     "name": "Monument / Landmark",
#                     "shortName": "Landmark",
#                     "id": "4bf58dd8d48988d12d941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/government_monument_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "345 George Street",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61132265",
#                 "twitter": "nab",
#                 "formattedPhone": "+61 13 22 65"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86801922378984,
#                         "lng": 151.20680809020996,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "345 George St.",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "345 George St.",
#                 "lat": -33.86801922378984,
#                 "lng": 151.20680809020996
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 1216,
#                 "usersCount": 111
#             },
#             "id": "4ba81355f964a520e7ca39e3",
#             "categories": [
#                 {
#                     "pluralName": "Buildings",
#                     "primary": true,
#                     "name": "Building",
#                     "shortName": "Building",
#                     "id": "4bf58dd8d48988d130941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Westfield Sydney",
#             "referralId": "v-1477449429",
#             "url": "http://www.westfield.com",
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [
#                 {
#                     "id": "556a302da7c8957d73d4510f"
#                 }
#             ],
#             "contact": {
#                 "facebookName": "Westfield",
#                 "twitter": "westfieldau",
#                 "phone": "+61282369200",
#                 "facebook": "225881920781330",
#                 "formattedPhone": "+61 2 8236 9200",
#                 "facebookUsername": "WestfieldSydney"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "188 Pitt St. (btwn Pitt St & Castlereagh St)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "btwn Pitt St & Castlereagh St",
#                 "address": "188 Pitt St.",
#                 "lat": -33.87033129768639,
#                 "lng": 151.20835736742308
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 135,
#                 "checkinsCount": 41016,
#                 "usersCount": 14531
#             },
#             "id": "4b8752c5f964a52079bb31e3",
#             "categories": [
#                 {
#                     "pluralName": "Shopping Malls",
#                     "primary": true,
#                     "name": "Shopping Mall",
#                     "shortName": "Mall",
#                     "id": "4bf58dd8d48988d1fd941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/mall_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "GPO Restaurants and Bars",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "url": "http://www.gpogrand.com",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61292297744",
#                 "formattedPhone": "+61 2 9229 7744"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86767874793018,
#                         "lng": 151.20789065165224,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1 Martin Pl. (Pitt St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "Pitt St.",
#                 "address": "1 Martin Pl.",
#                 "lat": -33.86767874793018,
#                 "lng": 151.20789065165224
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 7,
#                 "checkinsCount": 3129,
#                 "usersCount": 1172
#             },
#             "id": "4b0f36aef964a520756023e3",
#             "categories": [
#                 {
#                     "pluralName": "Food Courts",
#                     "primary": true,
#                     "name": "Food Court",
#                     "shortName": "Food Court",
#                     "id": "4bf58dd8d48988d120951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "City Recital Hall Angel Place",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "url": "http://www.cityrecitalhall.com/",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "events": {
#                 "count": 1,
#                 "items": [
#                     {
#                         "allDay": false,
#                         "startAt": 1477465200,
#                         "name": "Australian Brandenburg Orchestra and Avi Avital",
#                         "url": "http://www.songkick.com/concerts/27943429-australian-brandenburg-orchestra-at-city-recital-hall?utm_source=4436&utm_medium=partner",
#                         "text": "",
#                         "endAt": 1477486800,
#                         "provider": {
#                             "iconUrl": {
#                                 "prefix": "https://playfoursquare.s3.amazonaws.com/events/images/partners/sk/",
#                                 "name": "/logo.png",
#                                 "sizes": [
#                                     20,
#                                     40
#                                 ]
#                             },
#                             "name": "songkick",
#                             "urlText": "more info"
#                         },
#                         "images": [],
#                         "timeZone": "Australia/Sydney",
#                         "id": "57cfc407498e62727b63fd3e",
#                         "categories": [
#                             {
#                                 "pluralName": "Concerts",
#                                 "primary": true,
#                                 "name": "Concert",
#                                 "shortName": "Concert",
#                                 "id": "4e0a4b91bd41eda0d6092f89",
#                                 "icon": {
#                                     "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_",
#                                     "suffix": ".png"
#                                 }
#                             }
#                         ],
#                         "stats": {
#                             "checkinsCount": 0,
#                             "usersCount": 0
#                         }
#                     }
#                 ],
#                 "summary": "Australian Brandenburg Orchestra and Avi Avital"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61292319000",
#                 "twitter": "CityRecitalHall",
#                 "formattedPhone": "+61 2 9231 9000"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.866905860235875,
#                         "lng": 151.2076914441201,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "Angel Pl.",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "Angel Pl.",
#                 "lat": -33.866905860235875,
#                 "lng": 151.2076914441201
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 13,
#                 "checkinsCount": 1971,
#                 "usersCount": 963
#             },
#             "id": "4b05876af964a5205d9122e3",
#             "categories": [
#                 {
#                     "pluralName": "Concert Halls",
#                     "primary": true,
#                     "name": "Concert Hall",
#                     "shortName": "Concert Hall",
#                     "id": "5032792091d4c4b30a586d5c",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Sumo Salad",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.867704079999996,
#                         "lng": 151.206944,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "7 Barrack St.",
#                     "Sydney NSW",
#                     "Australia"
#                 ],
#                 "address": "7 Barrack St.",
#                 "lat": -33.867704079999996,
#                 "lng": 151.206944
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 5,
#                 "checkinsCount": 458,
#                 "usersCount": 169
#             },
#             "id": "4bcbca953740b7137c386365",
#             "categories": [
#                 {
#                     "pluralName": "Salad Places",
#                     "primary": true,
#                     "name": "Salad Place",
#                     "shortName": "Salad",
#                     "id": "4bf58dd8d48988d1bd941735",
#                     "icon": {
# ...
#                 "lat": -33.867695,
#                 "lng": 151.20734347500002
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 67,
#                 "usersCount": 45
#             },
#             "id": "4b1c475cf964a5206c0524e3",
#             "categories": [
#                 {
#                     "pluralName": "Jewelry Stores",
#                     "primary": true,
#                     "name": "Jewelry Store",
#                     "shortName": "Jewelry",
#                     "id": "4bf58dd8d48988d111951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/jewelry_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "CBD Health",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61292991311",
#                 "formattedPhone": "+61 2 9299 1311"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.867689,
#                         "lng": 151.207232,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1/343 George St. (Martin Place)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "Martin Place",
#                 "address": "1/343 George St.",
#                 "lat": -33.867689,
#                 "lng": 151.207232
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 73,
#                 "usersCount": 9
#             },
#             "id": "4bf1b9d13fa220a145a21820",
#             "categories": [
#                 {
#                     "pluralName": "Doctor's Offices",
#                     "primary": true,
#                     "name": "Doctor's Office",
#                     "shortName": "Doctor's Office",
#                     "id": "4bf58dd8d48988d177941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Peter Alexander",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86767351751292,
#                         "lng": 151.20737840421876,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "George St",
#                     "Sydney NSW",
#                     "Australia"
#                 ],
#                 "address": "George St",
#                 "lat": -33.86767351751292,
#                 "lng": 151.20737840421876
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 3,
#                 "checkinsCount": 160,
#                 "usersCount": 127
#             },
#             "id": "4b29a0a2f964a520e2a124e3",
#             "categories": [
#                 {
#                     "pluralName": "Boutiques",
#                     "primary": true,
#                     "name": "Boutique",
#                     "shortName": "Boutique",
#                     "id": "4bf58dd8d48988d104951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Tal Direct",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86803229493809,
#                         "lng": 151.20723611355905,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "formattedAddress": [
#                     "Australia"
#                 ],
#                 "lat": -33.86803229493809,
#                 "lng": 151.20723611355905
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 40,
#                 "usersCount": 5
#             },
#             "id": "5226b4fb498ef35676291f41",
#             "categories": [
#                 {
#                     "pluralName": "Offices",
#                     "primary": true,
#                     "name": "Office",
#                     "shortName": "Office",
#                     "id": "4bf58dd8d48988d124941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Crystal Boudoir",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86770611092685,
#                         "lng": 151.20723042193532,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "formattedAddress": [
#                     "Australia"
#                 ],
#                 "lat": -33.86770611092685,
#                 "lng": 151.20723042193532
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 10,
#                 "usersCount": 10
#             },
#             "id": "4e4fa4a3483bb7704911df25",
#             "categories": [
#                 {
#                     "pluralName": "Arts & Entertainment",
#                     "primary": true,
#                     "name": "Arts & Entertainment",
#                     "shortName": "Arts & Entertainment",
#                     "id": "4d4b7104d754a06370d81259",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Heritage Ballroom, Westin Hotel",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.867661005025425,
#                         "lng": 151.2073556377046,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "1 Martin Place (George Street)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "George Street",
#                 "address": "1 Martin Place",
#                 "lat": -33.867661005025425,
#                 "lng": 151.2073556377046
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 48,
#                 "usersCount": 44
#             },
#             "id": "4d9a5030bbf7b1f790c0944b",
#             "categories": [
#                 {
#                     "pluralName": "Convention Centers",
#                     "primary": true,
#                     "name": "Convention Center",
#                     "shortName": "Convention Center",
#                     "id": "4bf58dd8d48988d1ff931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/conventioncenter_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Marque Lawyers",
#             "referralId": "v-1477449429",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+61282163000",
#                 "formattedPhone": "+61 2 8216 3000"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.867684,
#                         "lng": 151.207346,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "343 George St",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "address": "343 George St",
#                 "lat": -33.867684,
#                 "lng": 151.207346
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 13,
#                 "usersCount": 7
#             },
#             "id": "4cb560837abcbfb762cba51f",
#             "categories": [
#                 {
#                     "pluralName": "Financial or Legal Services",
#                     "primary": true,
#                     "name": "Financial or Legal Service",
#                     "shortName": "Financial / Legal",
#                     "id": "503287a291d4c4b30a586d65",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/financial_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Louis Vuitton",
#             "referralId": "v-1477449429",
#             "venueChains": [
#                 {
#                     "id": "556ce4d6aceaff43eb05085e"
#                 }
#             ],
#             "url": "http://www.louisvuitton.com",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "+611300883880",
#                 "twitter": "louisvuitton",
#                 "formattedPhone": "+61 1300 883 880"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Sydney",
#                 "labeledLatLngs": [
#                     {
#                         "lat": -33.86871248605981,
#                         "lng": 151.20705398170125,
#                         "label": "display"
#                     }
#                 ],
#                 "cc": "AU",
#                 "country": "Australia",
#                 "postalCode": "2000",
#                 "state": "NSW",
#                 "formattedAddress": [
#                     "365 George St. (King St.)",
#                     "Sydney NSW 2000",
#                     "Australia"
#                 ],
#                 "crossStreet": "King St.",
#                 "address": "365 George St.",
#                 "lat": -33.86871248605981,
#                 "lng": 151.20705398170125
#             },
#             "beenHere": {
#                 "unconfirmedCount": 0,
#                 "marked": false,
#                 "lastCheckinExpiredAt": 0
#             },
#             "stats": {
#                 "tipCount": 10,
#                 "checkinsCount": 1477,
#                 "usersCount": 853
#             },
#             "id": "4e5da948fa768fe5f2bde5c0",
#             "categories": [
#                 {
#                     "pluralName": "Accessories Stores",
#                     "primary": true,
#                     "name": "Accessories Store",
#                     "shortName": "Accessories",
#                     "id": "4bf58dd8d48988d102951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/apparel_accessories_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# Now that we can make some sense of the structure let's practice traversing the JSON hieararchy, select one of the venues in the list and output it's name

# %%
# Solution
starting_list['venues'][17]['categories'][0]['name']
# Out:
# u'Concert Hall'

# %% [markdown]
# Note that the output isn't exactly what we want. It says u'Park', and if you check the type, Python will output Unicode. This isn't good, we need to recover the original intended type. Read the following docs:
#
# https://docs.python.org/2/library/unicodedata.html, and checkup the method 'normalize'. Once you think you've understood this method. Implement it on the above call and see if you can recover the appropriate type for that data.

# %% [markdown]
# Now for some exploratory analysis, let's print the number of total venues in your list

# %%
# Solution

len(starting_list['venues'])
# Out:
# 30

# %% [markdown]
# Extract the location id for your starting list. Make sure it's normalized to its correct type, and not Unicode. Put this id in a variable called temp. From this id, we will get a list of other venues.

# %%
starting_list['venues'][17]['id']
# Out:
# u'4b05876af964a5205d9122e3'

# %%
#starting_list['venues'][17]['name']
# Out:
# u'City Recital Hall Angel Place'

# %%
# Solution

temp = unicodedata.normalize('NFKD', starting_list['venues'][17]['id']).encode('ascii','ignore')
print(temp)
# Out:
# 4b05876af964a5205d9122e3

# %% [markdown]
# Print the venues list (in the nicely formatted JSON)

# %%
# Solution

temp1 = client.venues(temp);
print(json.dumps(temp1, indent = 4))
# Out:
# {
#     "venue": {
#         "rating": 8.6,
#         "reasons": {
#             "count": 1,
#             "items": [
#                 {
#                     "reasonName": "upcomingEventsReason",
#                     "type": "general",
#                     "target": {
#                         "object": {
#                             "ignorable": false,
#                             "type": "events",
#                             "id": "5810180938fa05a8b97596fc",
#                             "target": {
#                                 "url": "/venues/4b05876af964a5205d9122e3/events",
#                                 "type": "path"
#                             }
#                         },
#                         "type": "navigation"
#                     },
#                     "summary": "There is an upcoming event here"
#                 }
#             ]
#         },
#         "likes": {
#             "count": 61,
#             "groups": [
#                 {
#                     "count": 61,
#                     "items": [],
#                     "type": "others"
#                 }
#             ],
#             "summary": "61 Likes"
#         },
#         "beenHere": {
#             "count": 0,
#             "unconfirmedCount": 0,
#             "marked": false,
#             "lastCheckinExpiredAt": 0
#         },
#         "id": "4b05876af964a5205d9122e3",
#         "createdAt": 1258653546,
#         "description": "Initiated by the City of Sydney and held under a 99 year lease from the AMP Society, City Recital Hall Angel Place is managed by Pegasus Venue Management (AP) Pty Ltd.\r\n\r\n\"Science and art combine in Sydney's new recital hall to create an acoustic and aesthetic triumph\"\r\n\u2013 The Bulletin",
#         "verified": false,
#         "shortUrl": "http://4sq.com/6ObkD1",
#         "hereNow": {
#             "count": 0,
#             "groups": [],
#             "summary": "Nobody here"
#         },
#         "allowMenuUrlEdit": true,
#         "pageUpdates": {
#             "count": 0,
#             "items": []
#         },
#         "location": {
#             "city": "Sydney",
#             "labeledLatLngs": [
#                 {
#                     "lat": -33.866905860235875,
#                     "lng": 151.2076914441201,
#                     "label": "display"
#                 }
#             ],
#             "cc": "AU",
#             "country": "Australia",
#             "postalCode": "2000",
#             "state": "NSW",
#             "formattedAddress": [
#                 "Angel Pl.",
#                 "Sydney NSW 2000",
#                 "Australia"
#             ],
#             "address": "Angel Pl.",
#             "lat": -33.866905860235875,
#             "lng": 151.2076914441201
#         },
#         "dislike": false,
#         "bestPhoto": {
#             "suffix": "/Gtl_1tZf8t-dRur-oXjxTLE0gU4VUc6Em-Ya2t6h-hw.jpg",
#             "width": 537,
#             "visibility": "public",
#             "height": 720,
#             "source": {
#                 "url": "https://foursquare.com/download/#/iphone",
#                 "name": "Foursquare for iOS"
#             },
#             "prefix": "https://irs0.4sqi.net/img/general/",
#             "id": "501f4226e4b0d64f4377afaf",
#             "createdAt": 1344225830
#         },
#         "events": {
#             "count": 1,
#             "items": [
#                 {
#                     "allDay": false,
#                     "startAt": 1477465200,
#                     "name": "Australian Brandenburg Orchestra and Avi Avital",
#                     "url": "http://www.songkick.com/concerts/27943429-australian-brandenburg-orchestra-at-city-recital-hall?utm_source=4436&utm_medium=partner",
#                     "text": "",
#                     "endAt": 1477486800,
#                     "provider": {
#                         "iconUrl": {
#                             "prefix": "https://playfoursquare.s3.amazonaws.com/events/images/partners/sk/",
#                             "name": "/logo.png",
#                             "sizes": [
#                                 20,
#                                 40
#                             ]
#                         },
#                         "name": "songkick",
#                         "urlText": "more info"
#                     },
#                     "images": [],
#                     "timeZone": "Australia/Sydney",
#                     "id": "57cfc407498e62727b63fd3e",
#                     "categories": [
#                         {
#                             "pluralName": "Concerts",
#                             "primary": true,
#                             "name": "Concert",
#                             "shortName": "Concert",
#                             "id": "4e0a4b91bd41eda0d6092f89",
#                             "icon": {
#                                 "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_",
#                                 "suffix": ".png"
#                             }
#                         }
#                     ],
#                     "stats": {
#                         "checkinsCount": 0,
#                         "usersCount": 0
#                     }
#                 }
#             ],
#             "summary": "Australian Brandenburg Orchestra and Avi Avital"
#         },
#         "listed": {
#             "count": 13,
#             "groups": [
#                 {
#                     "count": 13,
#                     "items": [
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/enhancentertain/list/sydneys-event-venues",
#                             "editable": false,
#                             "listItems": {
#                                 "count": 22,
#                                 "items": [
#                                     {
#                                         "id": "v4b05876af964a5205d9122e3",
#                                         "createdAt": 1342165707
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1342165648,
#                             "public": true,
#                             "followers": {
#                                 "count": 3
#                             },
#                             "user": {
#                                 "gender": "none",
#                                 "isAnonymous": false,
#                                 "id": "32363228",
#                                 "firstName": "Enhance Entertainment",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/YJAUW2MJFCFEQ4ZG.png"
#                                 }
#                             },
#                             "updatedAt": 1364896730,
#                             "type": "others",
#                             "id": "4fffd290e4b02126b76ef705",
#                             "canonicalUrl": "https://foursquare.com/enhancentertain/list/sydneys-event-venues",
#                             "name": "Sydney's Event Venues"
#                         },
#                         {
#                             "description": "Este foi o 8\u00ba destino da Volta ao Mundo: Sydney, na Austr\u00e1lia. Os locais que o @Borbs mais curtiu voc\u00ea confere aqui!",
#                             "collaborative": false,
#                             "url": "/tamairlines/list/volta-ao-mundo-oneworld-sydney",
#                             "photo": {
#                                 "suffix": "/4142368_JBkwNjeZHjgJ5xE1ftbxn4MfXgojn0h_1h-_6Vp8N-I.jpg",
#                                 "visibility": "public",
#                                 "height": 720,
#                                 "width": 960,
#                                 "prefix": "https://irs0.4sqi.net/img/general/",
#                                 "user": {
#                                     "gender": "male",
#                                     "firstName": "Alex",
#                                     "lastName": "Romero",
#                                     "photo": {
#                                         "prefix": "https://irs3.4sqi.net/img/user/",
#                                         "suffix": "/ZBLGO2VL03R1OZ1Z.jpg"
#                                     },
#                                     "isAnonymous": false,
#                                     "id": "4142368"
#                                 },
#                                 "id": "51045d79e4b01e27b2316420",
#                                 "createdAt": 1359240569
#                             },
#                             "logView": true,
#                             "editable": false,
#                             "listItems": {
#                                 "count": 28,
#                                 "items": [
#                                     {
#                                         "photo": {
#                                             "suffix": "/38738380_L5DE8c_LaX6fPeGem71PjiI-54mpphwheRuGPBIqcZo.jpg",
#                                             "visibility": "public",
#                                             "height": 612,
#                                             "width": 612,
#                                             "prefix": "https://irs0.4sqi.net/img/general/",
#                                             "user": {
#                                                 "gender": "female",
#                                                 "firstName": "Molly",
#                                                 "lastName": "Hoffman",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/38738380-HQM13JFQOFRU4X0G.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "38738380"
#                                             },
#                                             "id": "50cd2288e4b0bd909fdf9065",
#                                             "createdAt": 1355621000
#                                         },
#                                         "id": "v4b05876af964a5205d9122e3",
#                                         "createdAt": 1402433152
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1402432837,
#                             "public": true,
#                             "followers": {
#                                 "count": 2
#                             },
#                             "user": {
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/ZMZFNVFDPOIRGX3Y.jpg"
#                                 },
#                                 "firstName": "TAM Airlines",
#                                 "gender": "none",
#                                 "type": "chain",
#                                 "isAnonymous": false,
#                                 "id": "12410747"
#                             },
#                             "updatedAt": 1402433532,
#                             "type": "others",
#                             "id": "53976d45498ebb1294956adb",
#                             "canonicalUrl": "https://foursquare.com/tamairlines/list/volta-ao-mundo-oneworld-sydney",
#                             "name": "Volta ao Mundo oneworld: Sydney"
#                         },
#                         {
#                             "description": "Mi pr\u00f3ximo gran viaje .-)",
#                             "collaborative": true,
#                             "url": "/josegdsm/list/australia",
#                             "photo": {
#                                 "suffix": "/940864_VYvXQt0kNC0REBm0Sq461rVkvU6H_-cJ3HBVmITFfWA.jpg",
#                                 "visibility": "public",
#                                 "height": 720,
#                                 "width": 720,
#                                 "prefix": "https://irs0.4sqi.net/img/general/",
#                                 "user": {
#                                     "gender": "male",
#                                     "firstName": "leesstyle",
#                                     "lastName": "- very lee\u2122",
#                                     "photo": {
#                                         "prefix": "https://irs0.4sqi.net/img/user/",
#                                         "suffix": "/-JT0TXN0SGQWMMJKO.jpg"
#                                     },
#                                     "isAnonymous": false,
#                                     "id": "940864"
#                                 },
#                                 "id": "513ab7ece4b0923337b7dfef",
#                                 "createdAt": 1362802668
#                             },
#                             "editable": false,
#                             "listItems": {
#                                 "count": 84,
#                                 "items": [
#                                     {
#                                         "id": "v4b05876af964a5205d9122e3",
#                                         "createdAt": 1364748444
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1362698133,
#                             "public": true,
#                             "followers": {
#                                 "count": 16
#                             },
#                             "user": {
#                                 "gender": "male",
#                                 "isAnonymous": false,
#                                 "id": "16952675",
#                                 "firstName": "Jos\u00e9",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/16952675-DRGRWNPSCYFGTJD2.jpg"
#                                 }
#                             },
#                             "updatedAt": 1376122926,
#                             "type": "others",
#                             "id": "51391f95e4b0f292e4aad549",
#                             "canonicalUrl": "https://foursquare.com/josegdsm/list/australia",
#                             "name": "Australia"
#                         },
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/kandilistk/list/places-to-visit-in-australia",
#                             "editable": false,
#                             "listItems": {
#                                 "count": 53,
#                                 "items": [
#                                     {
#                                         "id": "v4b05876af964a5205d9122e3",
#                                         "createdAt": 1355233243
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1355231938,
#                             "public": true,
#                             "followers": {
#                                 "count": 2
#                             },
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Tim",
#                                 "lastName": "Kandilis",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/3912252-NB2NFV1SPGADTN45.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "3912252"
#                             },
#                             "updatedAt": 1374851361,
#                             "type": "others",
#                             "id": "50c732c2e4b0f02263ac06f4",
#                             "canonicalUrl": "https://foursquare.com/kandilistk/list/places-to-visit-in-australia",
#                             "name": "Places to Visit in Australia"
#                         }
#                     ],
#                     "type": "others",
#                     "name": "Lists from other people"
#                 }
#             ]
#         },
#         "canonicalUrl": "https://foursquare.com/v/city-recital-hall-angel-place/4b05876af964a5205d9122e3",
#         "tags": [
#             "bravo",
#             "college",
#             "frat boys",
#             "music",
#             "photobooth"
#         ],
#         "photos": {
#             "count": 181,
#             "groups": [
#                 {
#                     "count": 181,
#                     "items": [
#                         {
#                             "suffix": "/Gtl_1tZf8t-dRur-oXjxTLE0gU4VUc6Em-Ya2t6h-hw.jpg",
#                             "width": 537,
#                             "visibility": "public",
#                             "height": 720,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "none",
#                                 "isAnonymous": false,
#                                 "id": "34118018",
#                                 "firstName": "Musica Viva",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/YBWUTH4XHQA4XGIH.jpg"
#                                 }
#                             },
#                             "id": "501f4226e4b0d64f4377afaf",
#                             "createdAt": 1344225830
#                         },
#                         {
#                             "suffix": "/34118018_-Gfvi9ib9y5mTyDpljIQsrOobwCkVPcKUlQn0Zp2B6Y.jpg",
#                             "width": 537,
#                             "visibility": "public",
#                             "height": 720,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs3.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "none",
#                                 "isAnonymous": false,
#                                 "id": "34118018",
#                                 "firstName": "Musica Viva",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/YBWUTH4XHQA4XGIH.jpg"
#                                 }
#                             },
#                             "id": "5056e5f2e4b0978a10ac1f3d",
#                             "createdAt": 1347872242
#                         },
#                         {
#                             "suffix": "/b-D5e2DsRauNJcFcvTqd1cmoxYFbWeTkZlQzceXon00.jpg",
#                             "width": 540,
#                             "visibility": "public",
#                             "height": 720,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Mal",
#                                 "lastName": "Booth",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/OBHLN0OP3SSPHLTP.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "2011096"
#                             },
#                             "id": "4f51ce67e4b07e4c61f62702",
#                             "createdAt": 1330761319
#                         },
#                         {
#                             "suffix": "/125532__UTdC9udJ7F8Xaj39HiTvJY7XMrgTZRgzAE3h_rg5PA.jpg",
#                             "width": 612,
#                             "visibility": "public",
#                             "height": 612,
#                             "source": {
#                                 "url": "http://instagram.com",
#                                 "name": "Instagram"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Arthur",
#                                 "lastName": "Lee",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/125532-33DHPUDNLVGHXFCW.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "125532"
#                             },
#                             "id": "51caba5c498e1c9692edc5cb",
#                             "createdAt": 1372240476
#                         },
#                         {
#                             "suffix": "/Gil4BNZLgKcUb2q7m76TY-mHDAqLUFieXi7-v-gNPU8.jpg",
#                             "width": 720,
#                             "visibility": "public",
#                             "height": 537,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs1.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Judith",
#                                 "lastName": "Cantor",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/JEVKOADMO2PNPAV0.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "2469591"
#                             },
#                             "id": "501ce351e4b09ed24486638b",
#                             "createdAt": 1344070481
#                         },
#                         {
#                             "suffix": "/QQMECBCNBJ2REZYLNKLJBULKW0ECAQUDUE1NKTXNQD5XQGDI.jpg",
#                             "width": 720,
#                             "visibility": "public",
#                             "height": 537,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs3.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "mike",
#                                 "lastName": "caulfield",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/5443729-WYORHRRBEK13Y5XS.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "5443729"
#                             },
#                             "id": "4ef037779a52cecf42b201f7",
#                             "createdAt": 1324365687
#                         }
#                     ],
#                     "type": "venue",
#                     "name": "Venue photos"
#                 }
#             ]
#         },
#         "attributes": {
#             "groups": [
#                 {
#                     "count": 5,
#                     "items": [
#                         {
#                             "displayValue": "Yes",
#                             "displayName": "Credit Cards"
#                         }
#                     ],
#                     "type": "payments",
#                     "name": "Credit Cards",
#                     "summary": "Credit Cards"
#                 }
#             ]
#         },
#         "stats": {
#             "tipCount": 13,
#             "checkinsCount": 1971,
#             "visitsCount": 2384,
#             "usersCount": 1277
#         },
#         "tips": {
#             "count": 13,
#             "groups": [
#                 {
#                     "count": 13,
#                     "items": [
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4f8b74a4e4b0e67b86f8dd91",
#                             "agreeCount": 2,
#                             "text": "One of the most beautiful venues in Sydney!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 2,
#                                 "groups": [
#                                     {
#                                         "count": 2,
#                                         "items": [
#                                             {
#                                                 "gender": "male",
#                                                 "firstName": "Kevin",
#                                                 "lastName": "Rainford",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/SBOULWQDW4WYOV13.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "516655"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "firstName": "Lisa",
#                                                 "lastName": "G",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/KUAV3ZSG2DOKMHR5.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "5882113"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "2 likes"
#                             },
#                             "type": "user",
#                             "id": "4f8b74a4e4b0e67b86f8dd91",
#                             "createdAt": 1334539428,
#                             "user": {
#                                 "gender": "none",
#                                 "isAnonymous": false,
#                                 "id": "26118320",
#                                 "firstName": "Musica Viva Australia",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/GPPHI13BCI5G43BF.jpg"
#                                 }
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4ba2c21470c603bb3de494b4",
#                             "agreeCount": 0,
#                             "text": "Work work work!!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 2,
#                                 "groups": [
#                                     {
#                                         "count": 2,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "2 likes"
#                             },
#                             "type": "user",
#                             "id": "4ba2c21470c603bb3de494b4",
#                             "createdAt": 1268957716,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Steph",
#                                 "lastName": "Zuniga",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/EX5DGTM3XSRRAWEU.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "313640"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/55e1b207498e6ee83dc898bb",
#                             "agreeCount": 1,
#                             "text": "comfortable :)",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 1,
#                                 "groups": [
#                                     {
#                                         "count": 1,
#                                         "items": [
#                                             {
#                                                 "gender": "female",
#                                                 "firstName": "Kiyoko",
#                                                 "lastName": "Yoshi",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/56030642-APCXJQK3RYBCE2EA.jpg"
#                                                 },
#                                                 "isAnonymous": false,
#                                                 "id": "56030642"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "1 like"
#                             },
#                             "type": "user",
#                             "id": "55e1b207498e6ee83dc898bb",
#                             "createdAt": 1440854535,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Mirai",
#                                 "lastName": "Uchi",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/56895507-HAC0OIRMP24VS23B.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "56895507"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/5555b445498e1aa91e78071b",
#                             "agreeCount": 0,
#                             "text": "Acoustics and beautiful space",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "authorInteractionType": "liked",
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "5555b445498e1aa91e78071b",
#                             "createdAt": 1431680069,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Kevin",
#                                 "lastName": "Rainford",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/SBOULWQDW4WYOV13.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "516655"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/54cce72f498e679b647f8734",
#                             "agreeCount": 0,
#                             "text": "Fantastic venue, if the bar on the first floor is crowded.... Go to the one on the second floor!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "authorInteractionType": "liked",
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "54cce72f498e679b647f8734",
#                             "createdAt": 1422714671,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "David",
#                                 "lastName": "Ma",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/W0EV5BQXEBCZCUWI.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "16002768"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/54c448f6498ecae9ac2fab2d",
#                             "agreeCount": 0,
#                             "text": "Great acoustics.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "authorInteractionType": "liked",
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "54c448f6498ecae9ac2fab2d",
#                             "createdAt": 1422149878,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Oliver",
#                                 "lastName": "Magro",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/4950818-LXTOIOPGFVE0A3SJ.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "4950818"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4ee6bdd1f790897ed29739e5",
#                             "agreeCount": 0,
#                             "url": "http://www.sydneyfestival.org.au/2012/Venues/City-Recital-Hall-Angel-Place/",
#                             "text": "This January, City Recital Hall sees Joshua Redman and Brad Mehldau reunited after 15 years for a night of jazz. You may also want to catch Assembly - an awe-inspiring mixture of movement and voice.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4ee6bdd1f790897ed29739e5",
#                             "createdAt": 1323744721,
#                             "user": {
#                                 "gender": "none",
#                                 "firstName": "Sydney",
#                                 "lastName": "Festival",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/HIJ2143BH3KZROPQ.png"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "2912311"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4e8da360f790e886ae030fe2",
#                             "agreeCount": 0,
#                             "text": "Seats are comfy, and great views from the balconies.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4e8da360f790e886ae030fe2",
#                             "createdAt": 1317905248,
#                             "user": {
#                                 "gender": "male",
#                                 "firstName": "Mark",
#                                 "lastName": "Nolte",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/3573271-U4STYRJO5YAHQES0.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "3573271"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4d3a31c636718eecba64738e",
#                             "agreeCount": 0,
#                             "text": "Festival Keynote: Hope 2011 - stories that must be told: Monday 24 January 2011. January offers a fresh start, the turning of a page and optimism for the year ahead.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4d3a31c636718eecba64738e",
#                             "createdAt": 1295659462,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Virginia",
#                                 "lastName": "Gordon",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/1OE5LACH3HRQNY3O.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "3427178"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4cdf436f534d594109681494",
#                             "agreeCount": 0,
#                             "url": "http://www.timeoutsydney.com.au/aroundtown/event/21817/inside-film-awards.aspx",
#                             "text": "Inside Film Awards, DateSun 14 NovWith its fast-paced awards ceremony and notorious after party, the Kodak IF Awards is widely known as one of the Aussie Film industry's best-loved events. Hosted th",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4cdf436f534d594109681494",
#                             "createdAt": 1289700207,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Ursula",
#                                 "lastName": "Hemard-Teri",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/H1HKD3D4MVD5AST0.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "3091807"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 2
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4cdb5a90adcc2c0f2051ae79",
#                             "agreeCount": 0,
#                             "url": "http://www.sydneyfestival.org.au/2011/Venues/City-Recital-Hall-Angel-Place/",
#                             "text": "In January Catch a great peformance at the City Recital hall for Sydney Festival, including Philip Glass, Beach House, Gotye and Paul Kelly!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4cdb5a90adcc2c0f2051ae79",
#                             "createdAt": 1289443984,
#                             "user": {
#                                 "gender": "none",
#                                 "firstName": "Sydney",
#                                 "lastName": "Festival",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/HIJ2143BH3KZROPQ.png"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "2912311"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4c16eb73127f9521fc502525",
#                             "agreeCount": 0,
#                             "text": "great for performances",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4c16eb73127f9521fc502525",
#                             "createdAt": 1276570483,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Steffie",
#                                 "lastName": "St Vincent",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/N0YLFFQEG0G32UH2.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "1657074"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 2
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4b5d42b570c603bbadca90b4",
#                             "agreeCount": 0,
#                             "url": "http://www.cityofsydney.nsw.gov.au/artandabout/ExhibitionsEvents/Laneways/ForgottenSongs.asp",
#                             "text": "FORGOTTEN SONGS @ Angel Place",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 0,
#                                 "groups": []
#                             },
#                             "type": "user",
#                             "id": "4b5d42b570c603bbadca90b4",
#                             "createdAt": 1264403125,
#                             "user": {
#                                 "gender": "female",
#                                 "firstName": "Yiying",
#                                 "lastName": "Lu",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/NPC1353XWNOCZ5EN.jpg"
#                                 },
#                                 "isAnonymous": false,
#                                 "id": "37104"
#                             }
#                         }
#                     ],
#                     "type": "others",
#                     "name": "All tips"
#                 }
#             ]
#         },
#         "categories": [
#             {
#                 "pluralName": "Concert Halls",
#                 "primary": true,
#                 "name": "Concert Hall",
#                 "shortName": "Concert Hall",
#                 "id": "5032792091d4c4b30a586d5c",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_",
#                     "suffix": ".png"
#                 }
#             },
#             {
#                 "shortName": "Building",
#                 "pluralName": "Buildings",
#                 "id": "4bf58dd8d48988d130941735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/building/default_",
#                     "suffix": ".png"
#                 },
#                 "name": "Building"
#             },
#             {
#                 "shortName": "Performing Arts",
#                 "pluralName": "Performing Arts Venues",
#                 "id": "4bf58dd8d48988d1f2931735",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_",
#                     "suffix": ".png"
#                 },
#                 "name": "Performing Arts Venue"
#             }
#         ],
#         "ok": false,
#         "name": "City Recital Hall Angel Place",
#         "url": "http://www.cityrecitalhall.com",
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "venueChains": [],
#         "contact": {
#             "phone": "+61292319000",
#             "twitter": "cityrecitalhall",
#             "formattedPhone": "+61 2 9231 9000"
#         },
#         "ratingSignals": 76,
#         "popular": {
#             "status": "Likely open",
#             "timeframes": [
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "Noon\u20133:00 PM"
#                         },
#                         {
#                             "renderedTime": "6:00 PM\u201310:00 PM"
#                         }
#                     ],
#                     "days": "Today",
#                     "includesToday": true
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "8:00 AM\u201310:00 AM"
#                         },
#                         {
#                             "renderedTime": "1:00 PM\u201310:00 PM"
#                         }
#                     ],
#                     "days": "Thu"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "9:00 AM\u201310:00 AM"
#                         },
#                         {
#                             "renderedTime": "6:00 PM\u201311:00 PM"
#                         }
#                     ],
#                     "days": "Fri"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "1:00 PM\u20132:00 PM"
#                         },
#                         {
#                             "renderedTime": "6:00 PM\u201310:00 PM"
#                         }
#                     ],
#                     "days": "Sat"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "4:00 PM\u20135:00 PM"
#                         },
#                         {
#                             "renderedTime": "7:00 PM\u20139:00 PM"
#                         }
#                     ],
#                     "days": "Sun"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "Noon\u20131:00 PM"
#                         },
#                         {
#                             "renderedTime": "6:00 PM\u20138:00 PM"
#                         }
#                     ],
#                     "days": "Mon"
#                 },
#                 {
#                     "segments": [],
#                     "open": [
#                         {
#                             "renderedTime": "8:00 AM\u201310:00 AM"
#                         },
#                         {
#                             "renderedTime": "3:00 PM\u20139:00 PM"
#                         }
#                     ],
#                     "days": "Tue"
#                 }
#             ],
#             "isLocalHoliday": false,
#             "isOpen": true
#         },
#         "timeZone": "Australia/Sydney",
#         "inbox": {
#             "count": 0,
#             "items": []
#         }
#     }
# }

# %% [markdown]
# Create a procedure that will only extract the comments in a list. There are a few ways you can do this, but I highly recommend you look up the map method from the base Python library: https://docs.python.org/2/tutorial/datastructures.html
#
# This is the same "map" function, that's one part of the map-reduce duo used in "Big Data" applications. So it may be helpful to get familiar with this method now if that's where you think you may want to take your career in the future.

# %%
# Solution
map(lambda h: h['text'], temp1['venue']['tips']['groups'][0]['items'])
# Out:
# [u'One of the most beautiful venues in Sydney!',
#  u'Work work work!!',
#  u'comfortable :)',
#  u'Acoustics and beautiful space',
#  u'Fantastic venue, if the bar on the first floor is crowded.... Go to the one on the second floor!',
#  u'Great acoustics.',
#  u'This January, City Recital Hall sees Joshua Redman and Brad Mehldau reunited after 15 years for a night of jazz. You may also want to catch Assembly - an awe-inspiring mixture of movement and voice.',
#  u'Seats are comfy, and great views from the balconies.',
#  u'Festival Keynote: Hope 2011 - stories that must be told: Monday 24 January 2011. January offers a fresh start, the turning of a page and optimism for the year ahead.',
#  u"Inside Film Awards, DateSun 14 NovWith its fast-paced awards ceremony and notorious after party, the Kodak IF Awards is widely known as one of the Aussie Film industry's best-loved events. Hosted th",
#  u'In January Catch a great peformance at the City Recital hall for Sydney Festival, including Philip Glass, Beach House, Gotye and Paul Kelly!',
#  u'great for performances',
#  u'FORGOTTEN SONGS @ Angel Place']

# %% [markdown]
# Now we're going to bring the above mini-tasks together into a nice little method, that will allow us to convert any foursquare JSON data into a nice tabular / rectangular table for further analysis. First instnatiate a pandas data frame.

# %%
venue_table = pd.DataFrame()

# %% [markdown]
# Write a procedure that will take your list of venues around a certain geography/lat/long whatever, and output a table that will have for each row, a comment associated for the venue (multiple comments will mean multiple rows, each per comment), the venue name, the tip count, the user count, and the store category. Make sure that each column is populated with appropriately typed values, i.e. names/categories should be strings, and numbers should be numerical data type.

# %% [markdown]
# **Hint**: Before you begin, think about the process. You're going to start with a loop of some kind, then think about the following:
# - How many of those do you need?
# - Think about the JSON structure, how "deep" do you need to penetrate the hierarchy to reach the data you want (this will help you think about how many loops you need for your crawler
# - How should you iteratively add on to your Pandas data frame?
# - Think of any tests you may need to put in to ensure your procedure does not cause an error (this may help you figure out how many if statements you may need, and where to place them.

# %%
for v_index in range(len(starting_list['venues'])-1):
    temp = unicodedata.normalize('NFKD', starting_list['venues'][v_index]['id']).encode('ascii','ignore')
    temp1 = client.venues(temp)
    print v_index
    comment_list = map(lambda h: h['text'], temp1['venue']['tips']['groups'][0]['items'])
    for c_index in range(len(comment_list)-1):
        print c_index
        comment_converter = unicodedata.normalize('NFKD', comment_list[c_index]).encode('ascii','ignore')
        print "test"
        if (starting_list['venues'][v_index]['categories']) != []:  
            venue_table = venue_table.append(pd.DataFrame({"name": unicodedata.normalize('NFKD', starting_list['venues'][v_index]['name']).encode('ascii','ignore'),
                                            "tip count": starting_list['venues'][v_index]['stats']['tipCount'],
                                            "users count": starting_list['venues'][v_index]['stats']['usersCount'],
                                             "store category": unicodedata.normalize('NFKD', starting_list['venues'][v_index]['categories'][0]['name']).encode('ascii','ignore'), 
                                             "comments": comment_converter}, index = [v_index + c_index]))
        else:
            venue_table = venue_table.append(pd.DataFrame({"name": unicodedata.normalize('NFKD', starting_list['venues'][v_index]['name']).encode('ascii','ignore'),
                                            "tip count": starting_list['venues'][v_index]['stats']['tipCount'],
                                            "users count": starting_list['venues'][v_index]['stats']['usersCount'],
                                             "store category": "No categories", 
                                             "comments": comment_converter}, index = [v_index + c_index]))
# Out:
# 0
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 12
# test
# 13
# test
# 14
# test
# 15
# test
# 16
# test
# 17
# test
# 18
# test
# 1
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 12
# test
# 13
# test
# 14
# test
# 15
# test
# 16
# test
# 17
# test
# 18
# test
# 2
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 12
# test
# 13
# test
# 14
# test
# 15
# test
# 16
# test
# 17
# test
# 18
# test
# 3
# 0
# test
# 1
# test
# 4
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 5
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 12
# test
# 13
# test
# 14
# test
# 15
# test
# 16
# test
# 6
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 7
# 0
# test
# 1
# test
# 8
# 9
# 10
# 11
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 12
# test
# 13
# test
# 14
# test
# 15
# test
# 16
# test
# 17
# test
# 18
# test
# 12
# 0
# test
# 1
# test
# 2
# test
# 13
# 14
# 15
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 12
# test
# 13
# test
# 14
# test
# 15
# test
# 16
# test
# 17
# test
# 18
# test
# 16
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 17
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 4
# test
# 5
# test
# 6
# test
# 7
# test
# 8
# test
# 9
# test
# 10
# test
# 11
# test
# 18
# 0
# test
# 1
# test
# 2
# test
# 3
# test
# 19
# 20
# 0
# test
# 1
# test
# 21
# 22
# 23
# 24
# 0
# test
# 1
# test
# 25
# 26
# 27
# 28

# %% [markdown]
# Finally, output the Venue table

# %%
venue_table.drop_duplicates()
# Out:
#                                              comments  \
# 0   Huge rooms for a downtown hotel. Great locatio...
# 1   View real guest photos & video of rooms at The...
# 2   Don't expect free bottled water for SPG platin...
# 3   Historical and ornate hotel in the hear of the...
# 4          Faster to Cut across lobby to get to gym .
# 5                     have a martini in the lobby bar
# 6   Recommend the Tower Premium Rooms and Exec Sui...
# 7   great gym set up perfect to keep up with my tr...
# 8   This is probably ground zero for Sydney CBD.  ...
# 9   Check out the High Tea Party happening on 8 an...
# 10                             Free wifi in the lobby
# 11  Super modern inside, the rooms feel like Apple...
# 12                                    Beautiful lobby
# 13  Nice Westin. Suite upgrades can be bit tight f...
# 14  As part of the Oct CSIFF 2011, enjoy late-nigh...
# 15  Love their lobby bar, sun streams in, make sur...
# 16                           5 stars! Super comfy bed
# 17                              Gorgeous 5 star hotel
# 18  Love this hotel with great location in the cit...
# 1   Go to Sydney in January. It's hot, but Sydney ...
# 2                 I love this city! Best in summer :)
# 3   it is a safe city to travel. get lost in the c...
# 4                      A view of Sydney from Space...
# 5   What better way to spend Christmas than climbi...
# 6                                    Best city in Aus
# 7   Places to go quickly: darling Harbour, Circula...
# 8   Only world class city in the Southern Hemisphe...
# 9   Catch A train into Central Station< head to Ge...
# 10  Sydney: where your taxi driver was a micro-sur...
# 11                                     Love this city
# ..                                                ...
# 30  finally new balance is open  !!! check out the...
# 31                       Free wifi and a LOT of shops
# 32  They have great clean toilets to take a bog in...
# 33                                Best mall in Sydney
# 16  Set a stop loss & don't have open positions ov...
# 17  Try the Pizza Patate & Rosmarino - Potato love...
# 18  Table bookings only available for 12pm and 1215pm
# 19                                  I'm bullish on BP
# 20  Try one of the cheese samplers at the cheese r...
# 21  Dimly lit "food court", not the most comfy. Fo...
# 17        One of the most beautiful venues in Sydney!
# 18                                   Work work work!!
# 19                                     comfortable :)
# 20                      Acoustics and beautiful space
# 21  Fantastic venue, if the bar on the first floor...
# 22                                   Great acoustics.
# 23  This January, City Recital Hall sees Joshua Re...
# 24  Seats are comfy, and great views from the balc...
# 25  Festival Keynote: Hope 2011 - stories that mus...
# 26  Inside Film Awards, DateSun 14 NovWith its fas...
# 27  In January Catch a great peformance at the Cit...
# 28                             great for performances
# 18  Need more staff at lunchtime, the wait is very...
# 19                Most of the staff just seem lost...
# 20  The soups are delicious! Plus you get a free b...
# 21  With the change in management things have impr...
# 20                                                  .
# 21  There used to be a great table tennis table on...
# 24  All the pajamas! Now selling accessories for y...
# 25  If you buy a gift set in one of the little pou...
#
#                              name              store category  tip count  \
# 0               The Westin Sydney                       Hotel         77
# 1               The Westin Sydney                       Hotel         77
# 2               The Westin Sydney                       Hotel         77
# 3               The Westin Sydney                       Hotel         77
# 4               The Westin Sydney                       Hotel         77
# 5               The Westin Sydney                       Hotel         77
# 6               The Westin Sydney                       Hotel         77
# 7               The Westin Sydney                       Hotel         77
# 8               The Westin Sydney                       Hotel         77
# 9               The Westin Sydney                       Hotel         77
# 10              The Westin Sydney                       Hotel         77
# 11              The Westin Sydney                       Hotel         77
# 12              The Westin Sydney                       Hotel         77
# 13              The Westin Sydney                       Hotel         77
# 14              The Westin Sydney                       Hotel         77
# 15              The Westin Sydney                       Hotel         77
# 16              The Westin Sydney                       Hotel         77
# 17              The Westin Sydney                       Hotel         77
# 18              The Westin Sydney                       Hotel         77
# 1                          Sydney                        City         26
# 2                          Sydney                        City         26
# 3                          Sydney                        City         26
# 4                          Sydney                        City         26
# 5                          Sydney                        City         26
# 6                          Sydney                        City         26
# 7                          Sydney                        City         26
# 8                          Sydney                        City         26
# 9                          Sydney                        City         26
# 10                         Sydney                        City         26
# 11                         Sydney                        City         26
# ..                            ...                         ...        ...
# 30               Westfield Sydney               Shopping Mall        135
# 31               Westfield Sydney               Shopping Mall        135
# 32               Westfield Sydney               Shopping Mall        135
# 33               Westfield Sydney               Shopping Mall        135
# 16       GPO Restaurants and Bars                  Food Court          7
# 17       GPO Restaurants and Bars                  Food Court          7
# 18       GPO Restaurants and Bars                  Food Court          7
# 19       GPO Restaurants and Bars                  Food Court          7
# 20       GPO Restaurants and Bars                  Food Court          7
# 21       GPO Restaurants and Bars                  Food Court          7
# 17  City Recital Hall Angel Place                Concert Hall         13
# 18  City Recital Hall Angel Place                Concert Hall         13
# 19  City Recital Hall Angel Place                Concert Hall         13
# 20  City Recital Hall Angel Place                Concert Hall         13
# 21  City Recital Hall Angel Place                Concert Hall         13
# 22  City Recital Hall Angel Place                Concert Hall         13
# 23  City Recital Hall Angel Place                Concert Hall         13
# 24  City Recital Hall Angel Place                Concert Hall         13
# 25  City Recital Hall Angel Place                Concert Hall         13
# 26  City Recital Hall Angel Place                Concert Hall         13
# 27  City Recital Hall Angel Place                Concert Hall         13
# 28  City Recital Hall Angel Place                Concert Hall         13
# 18                     Sumo Salad                 Salad Place          5
# 19                     Sumo Salad                 Salad Place          5
# 20                     Sumo Salad                 Salad Place          5
# 21                     Sumo Salad                 Salad Place          5
# 20                Macquarie Group  Financial or Legal Service          3
# 21                Macquarie Group  Financial or Legal Service          3
# 24                Peter Alexander                    Boutique          3
# 25                Peter Alexander                    Boutique          3
#
#     users count
# 0          3688
# 1          3688
# 2          3688
# 3          3688
# 4          3688
# 5          3688
# 6          3688
# 7          3688
# 8          3688
# 9          3688
# 10         3688
# 11         3688
# 12         3688
# 13         3688
# 14         3688
# 15         3688
# 16         3688
# 17         3688
# 18         3688
# 1         11206
# 2         11206
# 3         11206
# 4         11206
# 5         11206
# 6         11206
# 7         11206
# 8         11206
# 9         11206
# 10        11206
# 11        11206
# ..          ...
# 30        14531
# 31        14531
# 32        14531
# 33        14531
# 16         1172
# 17         1172
# 18         1172
# 19         1172
# 20         1172
# 21         1172
# 17          963
# 18          963
# 19          963
# 20          963
# 21          963
# 22          963
# 23          963
# 24          963
# 25          963
# 26          963
# 27          963
# 28          963
# 18          169
# 19          169
# 20          169
# 21          169
# 20          210
# 21          210
# 24          127
# 25          127
#
# [162 rows x 5 columns]

# %% [markdown]
# You've done it! You've built a simple crawler that traverses a JSON directory, and you've deposited the results in a nice Pandas data frame. Congratulations! You're now ready for more data-mining in the future, and have just beefed up the **data** part of the data science combination :)
