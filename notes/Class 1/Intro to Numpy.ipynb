# %%
import numpy

# %%
flat_array = numpy.arange(1,10,0.5)
flat_array
# Out:
# array([ 1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,  5.5,  6. ,
#         6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5])

# %%
flat_array.ptp()
# Out:
# 8.5

# %%
flat_array.mean(5)
# Out:
# 5.25

# %%
flat_array.sum()
# Out:
# 94.5

# %%
numpy.median(flat_array)
# Out:
# 5.25

# %%
one_dim = numpy.array([1,2,3,4,5,10])
one_dim
# Out:
# array([ 1,  2,  3,  4,  5, 10])

# %%
two_dim = numpy.array([
    [1,2,3],
    [2,3,4],
    [3,4,10]])
    
two_dim
# Out:
# array([[ 1,  2,  3],
#        [ 2,  3,  4],
#        [ 3,  4, 10]])

# %%
two_dim[2]
# Out:
# array([ 3,  4, 10])

# %%
two_dim[2][1]
# Out:
# 4

# %%
two_dim[2,1]
# Out:
# 4

# %%
dir(two_dim)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_wrap__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__delslice__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__hex__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
one_dim + 2
# Out:
# array([ 3,  4,  5,  6,  7, 12])

# %%
plus_two = one_dim + 2

# %%
plus_two + one_dim
# Out:
# array([ 4,  6,  8, 10, 12, 22])

# %%
one_dim * 3
# Out:
# array([ 3,  6,  9, 12, 15, 30])

# %%
one_dim * plus_two
# Out:
# array([  3,   8,  15,  24,  35, 120])

# %%
(one_dim * plus_two).sum()
# Out:
# 205

# %%
one_dim.dot(plus_two)
# Out:
# 205

# %%
one_mill = numpy.random.randint(0,1000,100000)
one_mill
# Out:
# array([953, 353, 320, ...,  33, 418, 361])

# %%
one_mill.shape
# Out:
# (100000,)

# %%
one_mill * 2
# Out:
# array([1906,  706,  640, ...,   66,  836,  722])

# %% [markdown]
# Compare speed: numpy vs. regular python list

# %%
one_mill = list(one_mill)

# %%
new_list = []
for i in range(len(one_mill)):
    new_list.append(one_mill[i]*2)
new_list
# Out:
# [1906,
#  706,
#  640,
#  1842,
#  1332,
#  188,
#  1736,
#  328,
#  760,
#  1254,
#  1640,
#  248,
#  1744,
#  592,
#  970,
#  1702,
#  0,
#  1746,
#  1142,
#  1726,
#  1788,
#  910,
#  1894,
#  1740,
#  1336,
#  1882,
#  24,
#  376,
#  1070,
#  1812,
#  970,
#  1452,
#  560,
#  822,
#  1622,
#  668,
#  1012,
#  1660,
#  1514,
#  484,
#  1926,
#  674,
#  1408,
#  1690,
#  108,
#  1052,
#  1464,
#  558,
#  1460,
#  1806,
#  1704,
#  994,
#  472,
#  1506,
#  1878,
#  586,
#  1388,
#  1032,
#  940,
#  496,
#  600,
#  1524,
#  1248,
#  286,
#  646,
#  610,
#  1056,
#  1632,
#  902,
#  1302,
#  22,
#  1142,
#  964,
#  1606,
#  1934,
#  6,
#  1466,
#  746,
#  1392,
#  1062,
#  178,
#  724,
#  1822,
#  378,
#  90,
#  1990,
#  1776,
#  1758,
#  934,
#  1338,
#  1026,
#  1930,
#  750,
#  176,
#  496,
#  782,
#  752,
#  1302,
#  1918,
#  82,
#  346,
#  944,
#  566,
#  1070,
#  30,
#  1710,
#  1810,
#  1024,
#  588,
#  1892,
#  392,
#  1118,
#  10,
#  906,
#  1968,
#  1264,
#  512,
#  1832,
# ...
