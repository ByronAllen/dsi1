# %% [markdown]
# # Project 4: Scrapping Data from Indeed.com
#
# ##### I build two key functions in this notebook
#
#
#
#
#
# *DataScienceJobSearch*
# * This function crawls across Indeed.com scrapping key data points from data scientist job posts in cities of your choice
#
# *SQLFunc*
# * This function was built as an exercise in streaming data to a local psql database

# %%
import requests
import urllib2
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import psycopg2
import string

# %%
df = pd.DataFrame()
pd.set_option('max_colwidth', 500)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#saving this function for another day

def SQLFunc(x):

    conn = psycopg2.connect(host = "localhost",
                            database="allenbyron",
                            port=5432)

    cur = conn.cursor()

    #Create sql query and execute
    sql_insert = 'insert into data_science_jobs (' + string.join(x[0], ', ') + ') values(' + ('%s, ' * (len(x) - 1)) + '%s' + ');'
    cur.execute(sql_insert, [i for i in x[1]])

    conn.commit()
    cur.close()
    conn.close()

# %%
def DataScienceJobSearch(city,df):
    
    jobs_scrapped = 0 #not useful when salary bins are taken into account 

    for c in city:        
        if c == 'Sydney' or c == 'Melbourne':
            home_url = 'http://au.indeed.com'
            base_url = 'http://au.indeed.com/jobs?q=data+scientist'
            loc_url = base_url + '&l=' + c
        else:
            home_url = 'http://www.indeed.com'
            base_url = 'http://www.indeed.com/jobs?q=data+scientist'
            loc_url = base_url + '&l=' + c
        
        #Identify salary bins
        estimated_salary = BeautifulSoup(urllib2.urlopen(loc_url), "lxml")
        rbList = estimated_salary.find('ul', attrs={'class': 'rbList'})
        salary_tuple = zip([i.getText() for i in rbList.find_all('a')],[i.get('href') for i in rbList.find_all('a')]) 
        print loc_url
        
        for s in salary_tuple:
            
            #Define salary bins
            salary_bins = s[0]
            bin_as_url_elem = salary_bins.split(',')[0] 
            
            salary_url = home_url + s[1]
            print salary_url
            content_for_range = BeautifulSoup(urllib2.urlopen(salary_url), "lxml")

            #Define max of range
            try:
                searchCount = content_for_range.find('div', attrs={'id': 'searchCount'}).getText().strip()
                number_of_results = str(searchCount).split(' ')
                max_of_range = int(number_of_results[-1]) 
                var = int(round((max_of_range/10)) + 2)
            except:
                var = 100
            
            #change max of range to var if not var
            for page in range(1, var): 
                page = (page-1) * 10  
                start_of_url = '/jobs?q=data+scientist+%24'
                mid_url = '%2C000&l='
                start_from = '&start='  # start page number
                url = "%s%s%s%s%s%s%d" % (home_url, start_of_url, bin_as_url_elem, mid_url, c, start_from, page) 
                print url
                
                contents = BeautifulSoup(urllib2.urlopen(url), "lxml") 
                contentsElements = contents.find_all('div', attrs={'class': ' row result'}) 

                for job in contentsElements:
                    
                    jobs_scrapped += 1         
                    
                    #Details of the job
                    try: job_title = job.find('h2', attrs={'class':'jobtitle'}).getText().strip()
                    except: job_title = '-' #None

                    try: company = job.find('span', attrs={'itemprop':'name'}).getText().strip()
                    except: company = '-' #None

                    try: salary = job.find('nobr').getText().strip() 
                    except: salary = '-' #None

                    try: reviews_total = job.find('span', attrs={'class':'slNoUnderline'}).getText().strip()
                    except: reviews_total = '-' #None

                    try: job_description = job.find('span', attrs={'itemprop':'description'}).getText()
                    except: job_description = '-' #None

                    try: link = "%s%s" % (home_url, job.find('a').get('href'))
                    except: link = '-' #None

                    try: job_addr = job.find('span', attrs={'itemprop':'addressLocality'}).getText()
                    except: job_addr = '-' #None

                    try: job_posted = job.find('span', attrs={'class': 'date'}).getText()   
                    except: job_posted = '-' #None



                    #Company page
                    try:
                        indeed_company_url = "%s%s%s" % (home_url, '/cmp/', company.replace(' ','-'))
                        indeed_company_page = BeautifulSoup(urllib2.urlopen(indeed_company_url), "lxml")
                    except:
                        #print Exception, 'problem with indeed_company_url', company
                        continue


                    #Glean overall company rating 
                    try:
                        company_overall_ratingElements = indeed_company_page.find_all('div', attrs={'id':'cmp-reviews'})
                        for score in company_overall_ratingElements:
                            reviews_score = score.find('span', attrs={'class':'cmp-average-rating'}).getText().strip()
                    except:
                        reviews_score = '-' #None


                    #Glean various company ratings
                    try:
                        specific_ratingsElements = indeed_company_page.find('dl', attrs={'id':'cmp-reviews-attributes'})    
                        specific_ratingsElements = specific_ratingsElements.find_all('span', attrs={'class': 'cmp-star-rating'})

                        if specific_ratingsElements != None:

                            #print 'specific_ratingsElements'

                            if specific_ratingsElements[0] != None:
                                #print 'first element has something'

                                try: work_life_bal = specific_ratingsElements[0].getText()
                                except: work_life_bal = '-' #None

                                try: salary_benefits = specific_ratingsElements[1].getText()
                                except: salary_benefits = '-' #None

                                try: job_security_advance = specific_ratingsElements[2].getText()
                                except: job_security_advance = '-' #None

                                try: management = specific_ratingsElements[3].getText()
                                except: management = '-' #None

                                try: culture = specific_ratingsElements[4].getText()
                                except: culture = '-' #None        

                            else:
                                #print 'first element has nothing'

                                try: work_life_bal = specific_ratingsElements[1].getText()
                                except: work_life_bal = '-' #None

                                try: salary_benefits = specific_ratingsElements[2].getText()
                                except: salary_benefits = '-' #None

                                try: job_security_advance = specific_ratingsElements[3].getText()
                                except: job_security_advance = '-' #None

                                try: management = specific_ratingsElements[4].getText()
                                except: management = '-' #None

                                try: culture = specific_ratingsElements[5].getText()
                                except: culture = '-' #None   

                    except:
                        #print 'specific_ratingsElements is empty'

                        work_life_bal = '-' #None
                        salary_benefits = '-' #None
                        job_security_advance = '-' #None
                        management = '-' #None
                        culture = '-' #None   

                    #print '...........................'

                    df = df.append({'job_title': job_title,
                                    'company': company,
                                    'salary': salary,
                                    'reviews_total': reviews_total,
                                    'reviews_score': reviews_score,
                                    'job_description': job_description,
                                    'link': link,
                                    'job_addr': job_addr,
                                    'job_posted': job_posted,
                                    'work_life_bal': work_life_bal,
                                    'salary_benefits': salary_benefits,
                                    'job_security_advance': job_security_advance,
                                    'management': management,
                                    'culture': culture,
                                    'salary_bins': salary_bins
                                    }, ignore_index=True)
                    
                    #SQLFunc #Alternative choice to df.append()
    
    return df

# %%
list_of_cities = ['Austin'] #'Sydney','Melbourne', 'San+Francisco', 'Austin', 'Chicago'
job_searches = DataScienceJobSearch(list_of_cities,df)
job_searches
# Out:
# http://www.indeed.com/jobs?q=data+scientist&l=Chicago
# http://www.indeed.com/q-data-scientist-$55,000-l-Chicago-jobs.html
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=0
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=10
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=20
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=30
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=40
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=50
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=60
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=70
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=80
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=90
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=100
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=110
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=120
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=130
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=140
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=150
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=160
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=170
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=180
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=190
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=200
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=210
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=220
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=230
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=240
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=250
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=260
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=270
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=280
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=290
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=300
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=310
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=320
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=330
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=340
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=350
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=360
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=370
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=380
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=390
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=400
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=410
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=420
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=430
# http://www.indeed.com/jobs?q=data+scientist+%24$55%2C000&l=Chicago&start=440
# http://www.indeed.com/q-data-scientist-$70,000-l-Chicago-jobs.html
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=0
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=10
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=20
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=30
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=40
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=50
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=60
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=70
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=80
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=90
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=100
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=110
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=120
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=130
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=140
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=150
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=160
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=170
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=180
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=190
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=200
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=210
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=220
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=230
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=240
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=250
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=260
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=270
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=280
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=290
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=300
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=310
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=320
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=330
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=340
# http://www.indeed.com/jobs?q=data+scientist+%24$70%2C000&l=Chicago&start=350
# http://www.indeed.com/q-data-scientist-$85,000-l-Chicago-jobs.html
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=0
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=10
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=20
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=30
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=40
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=50
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=60
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=70
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=80
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=90
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=100
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=110
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=120
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=130
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=140
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=150
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=160
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=170
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=180
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=190
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=200
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=210
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=220
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=230
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=240
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=250
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=260
# http://www.indeed.com/jobs?q=data+scientist+%24$85%2C000&l=Chicago&start=270
# http://www.indeed.com/q-data-scientist-$105,000-l-Chicago-jobs.html
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=0
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=10
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=20
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=30
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=40
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=50
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=60
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=70
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=80
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=90
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=100
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=110
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=120
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=130
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=140
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=150
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=160
# http://www.indeed.com/jobs?q=data+scientist+%24$105%2C000&l=Chicago&start=170
# http://www.indeed.com/q-data-scientist-$120,000-l-Chicago-jobs.html
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=0
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=10
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=20
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=30
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=40
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=50
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=60
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=70
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=80
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=90
# http://www.indeed.com/jobs?q=data+scientist+%24$120%2C000&l=Chicago&start=100
#                                       company culture  \
# 0          The University of Chicago Medicine     3.8
# 1                                        Amyx       -
# 2                                   RAY ALLEN       -
# 3                                      ZirMed     4.0
# 4                              Valence Health     2.9
# 5                                 Caterpillar     3.7
# 6                                   Cognizant     3.9
# 7                           Wolverine Trading     5.0
# 8                        Dupage Medical Group     2.9
# 9                        Dupage Medical Group     2.9
# 10                             Valence Health     2.9
# 11            Illinois Technology Association       -
# 12                                Iris Mobile     2.0
# 13                           MAKE Corporation     3.4
# 14                            Civis Analytics     5.0
# 15            Illinois Technology Association       -
# 16                                     Orbitz     3.9
# 17                                  Honeywell     3.7
# 18                           Conversant Media     3.6
# 19                                       KPMG     3.8
# 20                      Workbridge Associates     3.3
# 21                                   Hirewell     5.0
# 22                                 NJF Search       -
# 23                         Empowered Staffing       -
# 24                           General Assembly     4.1
# 25    National Opinion Research Center (NORC)     2.6
# 26                              Spencer Ogden     3.5
# 27                              W.W. Grainger     3.7
# 28                                    Precima     5.0
# 29                            Civis Analytics     5.0
# ...                                       ...     ...
# 1014                            Vizient, Inc.       -
# 1015                                    Dyson     3.5
# 1016                         All-In Analytics       -
# 1017                   Mondelez International     3.6
# 1018                          Civis Analytics     5.0
# 1019                       York Solutions LLC     4.0
# 1020                          Civis Analytics     5.0
# 1021                    Big Wednesday Digital       -
# 1022                                  Experis     3.6
# 1023                  The Climate Corporation     4.5
# 1024                                   Bolstr       -
# 1025              Argonne National Laboratory     3.9
# 1026                          Civis Analytics     5.0
looking for bright and energetic individuals to fill a data scientist position in our Analytic Services department....
# 5                              \nCaterpillar is hiring the best data scientists to join its newly opened Digital & Analytics Hub within the Merchandise Mart in Chicago....
# 6                              \nScale data manipulation and mining/pattern recognition. Statistical analysis large scale data manipulation Monte Carlo simulation. Job....
# 7             \nMachine Learning Data Scientist. You will be using large data sets to create trading strategies, improve trading, quantitative research and data mining....
# 8                                                       \n3+ years' experience analyzing large data sets. Experience with healthcare data – both clinical and financial....
# 9                                                       \n3+ years' experience analyzing large data sets. Experience with healthcare data – both clinical and financial....
# 10                                          \nWe are looking for bright and energetic individuals to fill a data scientist position in our Analytic Services department....
# 11    \nData Scientist -Speech Recognition. Writing software to clean and investigate large, messy data sets of unstructured data, for example, speech/audio, image, and...
# 12            \nPractical ability to visualize data, communicate about the data, and utilize it effectively. Develop machine learning models to better process our data....
# 13                               \nDevelop data science expertise. Identifying opportunities to innovate on top of the CLS data, which promote skills in Data Analytics....
# 14        \nWith a specialization in unstructured data, this Data Scientist role will apply techniques from fields such as machine learning, applied statistics, natural...
# 15         \nWriting software to clean and investigate large, messy data sets of numerical and textual data. Integrating with external data sources and APIs to discover...
# 16                                           \nSEM Data Scientist. Experienced dealing with big data. Experienced in data modeling, reporting and business intelligence....
# 17                                                         \nProviding process control and data acquisition support for the pilot plant and laboratory plant operations....
# 18                                                               \nAs a Data Scientist in. Alliance Data will. Alliance Data is an. Epsilon is an Alliance Data company....
# 19          \nFive years of professional experience working as a Data Scientist. Machine learning, data visualization, statistical modeling, data mining, or information...
# 20                   \nData, Analytics, Scientist, Science, Python, R, SAS, SQL, Hadoop, Tableau, Analysis, Healthcare, Hospital, University, Career, Job, Chicago, IL,....
# 21             \nPractical ability to visualize data, communicate about the data and utilize it effectively. You will be addressing challenging data science problems by...
# 22       \nAs a data scientist you will be applying statistical modelling techniques to huge structured, and unstructured data sets with a view to optimize these models...
# 23     \nStructure current data into Data Warehouse | Data through acquisitions. 2-5+ years with data engineering, data science or data analysis in eCommerce or Medical...
# 24         \nData visualization techniques; Manipulation of large data sets; You are eager to shape the skills, minds, and trajectories of the newest generation of data...
# 25       \nInterpreting data from multiple sources; At NORC, Data Scientists play a strategic role in supporting our research teams to produce valuable insights for our...
# 26          \nKey Responsibilities · Perform production estimates for solar PV projects using production estimation software such as PVSYST, PVWATTS, SAM, and Helioscope ·
# 27      \nExplore data sets and identify data transformation and data quality needs for targeted applications. Hands-on software engineering and data science experience...
# 28                             \nThe Data Scientist will provide process execution support for client projects. Take analytical objectives and define data requirements....
# 29    \nExperience identifying and adapting to imperfect data. Applied Data Scientists collaborate with clients, Civis Analytics’ R&D and Technology teams, and managers...
# ...                                                                                                                                                                     ...
# 1014          \nProvides coordination for member risk adjustment task force include clinicians and data scientists. Works with member task force and Center for Advanced...
# 1015                                \nDyson sells products in 71 countries, and it employs almost 6,000 people globally, one third of whom are engineers and scientists....
# 1016    \nLooking for a seasoned manager very strong in machine learning and big data to build and lead a team of data scientists and engineers at a Fortune 100 company...
# 1017  \nExperience with tools and processes related to enterprise data management (global/ regional data warehouse, big data environments, metadata management processes...
# 1018                  \nOur engineers, data scientists and analysts are not only the best and brightest in their fields, but are also eager to teach and learn from you....
# 1019                                       \n Work with Business Analysts, Application Developers and Data Scientists to implement solutions using agile methodologies....
# 1020        \nPolitical technology and data. Data visualization for the web (using D3 or similar). Engineers collaborate across departments with our data scientists and...
# 1021                                        \nTheir systems scale across multiple data centers, totaling a few million writes per second and managing petabytes of data....
# 1022                                              \nProven experience with logical / physical data modeling across a number of different data management platforms (i.e....
# 1023   \nYou will have the opportunity to work with large, "big data" sets such as scientific data, machine generated data from our farmer's equipment, geospatial data,...
# 1024                              \nExcited to use your experience to build a credit methodology and decision tree from scratch alongside a wicked smart data scientist....
# 1025               \nThe KBase data interfaces (for sharing, displaying and accessing biological data),. Experience working with scientific datasets and developing data...
# 1026        \nPolitical technology and data. Data visualization for the web (using D3 or similar). Engineers collaborate across departments with our data scientists and...
# 1027                                                  \nDoing all this with an exceptional group of software engineers, data scientists, dev-ops engineers and managers....
# 1028                     \nLine management responsibilities for junior physicians and/or scientists. Review of safety data and participate in dose escalation decisions....
# 1029  \nDevelop data mining and/or data modeling plans to support RWI&A projects and programs. Manage, mentor and develop a high performing data scientists team through...
# 1030       \n Supervise 1-3 junior CPED scientists.  May have functional management of scientists.  May have direct reporting CPED scientists who are responsible for...
# 1031                              \nExcited to use your experience to build a credit methodology and decision tree from scratch alongside a wicked smart data scientist....
# 1032     \nVice President, Analytics, Downtown, SQL, BI Tools, VBA, Python, Java, Agile Methodologies, Data Science, Data Engineer, Marketing Analytics, Data Scientist,...
# 1033                                                  \nDoing all this with an exceptional group of software engineers, data scientists, dev-ops engineers and managers....
# 1034  \nDevelop data mining and/or data modeling plans to support RWI&A projects and programs. Manage, mentor and develop a high performing data scientists team through...
# 1035                     \nLine management responsibilities for junior physicians and/or scientists. Review of safety data and participate in dose escalation decisions....
# 1036  \nUnderstanding of analytics roles and responsibilities (e.g., data scientist). Accenture has a team of more than 36,000 digital professionals including technical...
# 1037       \n Supervise 1-3 junior CPED scientists.  May have functional management of scientists.  May have direct reporting CPED scientists who are responsible for...
# 1038        \nPolitical technology and data. Data visualization for the web (using D3 or similar). Engineers collaborate across departments with our data scientists and...
# 1039                                                  \nDoing all this with an exceptional group of software engineers, data scientists, dev-ops engineers and managers....
# 1040                     \nLine management responsibilities for junior physicians and/or scientists. Review of safety data and participate in dose escalation decisions....
# 1041  \nDevelop data mining and/or data modeling plans to support RWI&A projects and programs. Manage, mentor and develop a high performing data scientists team through...
# 1042       \n Supervise 1-3 junior CPED scientists.  May have functional management of scientists.  May have direct reporting CPED scientists who are responsible for...
# 1043                              \nExcited to use your experience to build a credit methodology and decision tree from scratch alongside a wicked smart data scientist....
#
#         job_posted job_security_advance  \
# 0     13 hours ago                  3.8
# 1       3 days ago                    -
# 2       2 days ago                    -
# 3       8 days ago                  3.5
# 4      19 days ago                  2.3
# 5      13 days ago                  3.2
# 6      16 days ago                  4.0
# 7      15 days ago                  3.0
# 8      8 hours ago                  2.6
# 9      8 hours ago                  2.6
# 10     19 days ago                  2.3
# 11     12 days ago                    -
# 12    30+ days ago                  1.0
# 13     13 days ago                  2.2
# 14     16 days ago                  3.0
# 15     12 days ago                    -
# 16    30+ days ago                  3.1
# 17       1 day ago                  3.3
# 18    30+ days ago                  3.3
# 19     14 days ago                  3.8
# 20     12 days ago                  2.9
# 21      7 days ago                  5.0
# 22      8 days ago                    -
# 23     15 days ago                    -
# 24      3 days ago                  3.8
# 25    30+ days ago                  2.0
# 26    30+ days ago                  3.5
# 27    30+ days ago                  3.3
# 28    30+ days ago                  4.0
# 29     29 days ago                  3.0
# ...            ...                  ...
# 1014   26 days ago                    -
# 1015   12 days ago                  3.1
# 1016  30+ days ago                    -
# 1017  30+ days ago                  3.2
# 1018  30+ days ago                  3.0
# 1019   23 days ago                  1.0
# 1039                                                          http://www.indeed.com/rc/clk?jk=7a3965aa8c36a6d3&fccid=028ef7f5b4e7c045
# 1040                         http://www.indeed.com/cmp/Klinexa-Inc./jobs/Medical-Director-16cae1ff9364fe77?r=1&fccid=60d23db826e4091d
# 1041                                                          http://www.indeed.com/rc/clk?jk=df8548b2aafbf8e0&fccid=889299755eb998cd
# 1042                                                          http://www.indeed.com/rc/clk?jk=4bab328a3253ec24&fccid=889299755eb998cd
# 1043                                                          http://www.indeed.com/rc/clk?jk=677e75849ece52b4&fccid=fb9bbcab76f046d3
#
#      management reviews_score  reviews_total                      salary  \
# 0           3.6           4.3      7 reviews                           -
# 1             -           4.3              -                           -
# 2             -           4.3              -                           -
# 3           4.3           4.0      5 reviews                           -
# 4           2.5           2.9              -                           -
# 5           3.4           3.9  1,964 reviews                           -
# 6           3.6           4.0  4,678 reviews                           -
# 7           4.0           4.0              -                           -
# 8           2.6           3.1     70 reviews                           -
# 9           2.6           3.1     70 reviews                           -
# 10          2.5           2.9              -                           -
# 11            -           2.9              -                           -
# 12          3.0           2.0              -                           -
# 13          3.4           4.4              -                           -
# 14          3.0           4.0              -                           -
# 15            -           4.0              -                           -
# 16          3.8           4.2     30 reviews                           -
# 17          3.5           3.9  3,447 reviews                           -
# 18          3.2           3.9      9 reviews                           -
# 19          3.7           4.0  1,759 reviews                           -
# 20          3.4           3.3     24 reviews             $105,000 a year
# 21          5.0           5.0              -              $85,000 a year
# 22            -           5.0              -                           -
# 23            -           5.0              -                           -
# 24          4.0           4.3     74 reviews                           -
# 25          2.3           2.8              -                           -
# 26          3.3           3.4      7 reviews                           -
# 27          3.3           3.9  1,020 reviews                           -
# 28          5.0           4.0              -                           -
# 29          3.0           4.0              -                           -
# ...         ...           ...            ...                         ...
# 1014          -           4.0              -                           -
# 1015        3.1           3.7     54 reviews                           -
# 1016          -           3.7              -                           -
# 1017        3.4           3.8    640 reviews                           -
# 1018        3.0           4.0              -                           -
# 1019        5.0           4.0              -                           -
# 1020        3.0           4.0              -                           -
# 1021          -           4.0              -   $50,000 - $125,000 a year
# 1022        3.4           3.8    293 reviews                           -
# 1023        3.0           4.5      2 reviews                           -
# 1024          -           4.5              -                           -
# 1025        3.6           4.2     79 reviews                           -
# 1026        3.0           4.0              -                           -
# 1027        4.3           4.8      4 reviews                           -
# 1028          -           4.8              -                           -
# 1029        3.0           3.7     50 reviews                           -
# 1030        3.0           3.7     50 reviews                           -
# 1031          -           3.7              -                           -
# 1032        3.2           3.3     12 reviews  $160,000 - $180,000 a year
# 1033        4.3           4.8      4 reviews                           -
# 1034        3.0           3.7     50 reviews                           -
# 1035          -           3.7              -                           -
# 1036        3.6           4.0  6,848 reviews                           -
# 1037        3.0           3.7     50 reviews                           -
# 1038        3.0           4.0              -                           -
# 1039        4.3           4.8      4 reviews                           -
# 1040          -           4.8              -                           -
# 1041        3.0           3.7     50 reviews                           -
# 1042        3.0           3.7     50 reviews                           -
# 1043          -           3.7              -                           -
#
#      salary_benefits salary_bins work_life_bal
# 0                4.0    $55,000+           4.0
# 1                  -    $55,000+             -
# 2                  -    $55,000+             -
# 3                4.5    $55,000+           4.3
# 4                3.0    $55,000+           2.8
# 5                3.9    $55,000+           3.8
# 6                3.5    $55,000+           3.8
# 7                3.0    $55,000+           5.0
# 8                2.7    $55,000+           3.2
# 9                2.7    $55,000+           3.2
# 10               3.0    $55,000+           2.8
# 11                 -    $55,000+             -
# 12               3.0    $55,000+           1.0
# 13               3.0    $55,000+           3.6
# 14               3.0    $55,000+           4.0
# 15                 -    $55,000+             -
# 16               3.8    $55,000+           4.4
# 17               3.6    $55,000+           3.7
# 18               4.0    $55,000+           4.0
# 19               3.6    $55,000+           3.4
# 20               2.8    $55,000+           3.0
# 21               5.0    $55,000+           5.0
# 22                 -    $55,000+             -
# 23                 -    $55,000+             -
# 24               4.1    $55,000+           4.0
# 25               2.1    $55,000+           3.1
# 26               3.7    $55,000+           4.0
# 27               3.9    $55,000+           3.7
# 28               2.0    $55,000+           3.0
# 29               3.0    $55,000+           4.0
# ...              ...         ...           ...
# 1014               -   $120,000+             -
# 1015             3.3   $120,000+           3.6
# 1016               -   $120,000+             -
# 1017             3.8   $120,000+           3.6
# 1018             3.0   $120,000+           4.0
# 1019             4.0   $120,000+           5.0
# 1020             3.0   $120,000+           4.0
# 1021               -   $120,000+             -
# 1022             3.5   $120,000+           3.7
# 1023             4.5   $120,000+           4.0
# 1024               -   $120,000+             -
# 1025             3.9   $120,000+           4.1
# 1026             3.0   $120,000+           4.0
# 1027             4.3   $120,000+           4.7
# 1028               -   $120,000+             -
# 1029             4.0   $120,000+           3.5
# 1030             4.0   $120,000+           3.5
# 1031               -   $120,000+             -
# 1032             2.8   $120,000+           2.8
# 1033             4.3   $120,000+           4.7
# 1034             4.0   $120,000+           3.5
# 1035               -   $120,000+             -
# 1036             3.6   $120,000+           3.7
# 1037             4.0   $120,000+           3.5
# 1038             3.0   $120,000+           4.0
# 1039             4.3   $120,000+           4.7
# 1040               -   $120,000+             -
# 1041             4.0   $120,000+           3.5
# 1042             4.0   $120,000+           3.5
# 1043               -   $120,000+             -
#
# [1044 rows x 15 columns]

# %%
print job_searches.shape
job_searches.drop_duplicates(subset = ['company', 'job_description', 'job_title', 'link'], keep='last',inplace=True)
# Out:
# (1044, 15)

# %%
job_searches.reviews_score = job_searches.reviews_score.astype(np.float_)
job_searches['salary_bins_int'] = [x.replace('$', '').replace(',', '').replace('+','') for x in job_searches.salary_bins]
job_searches.reviews_total = [x.replace(' reviews', '') for x in job_searches.reviews_total]
job_searches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 309 entries, 2 to 1043
# Data columns (total 16 columns):
# company                 309 non-null object
# culture                 309 non-null object
# job_addr                309 non-null object
# job_description         309 non-null object
# job_posted              309 non-null object
# job_security_advance    309 non-null object
# job_title               309 non-null object
# link                    309 non-null object
# management              309 non-null object
# reviews_score           309 non-null float64
# reviews_total           309 non-null object
# salary                  309 non-null object
# salary_benefits         309 non-null object
# salary_bins             309 non-null object
# work_life_bal           309 non-null object
# salary_bins_int         309 non-null object
# dtypes: float64(1), object(15)
# memory usage: 41.0+ KB

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
job_searches.to_csv('chi_job_searches.csv', index=False)
