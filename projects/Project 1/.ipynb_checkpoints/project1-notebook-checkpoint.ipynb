# %% [markdown]
# # Project 1 Notebook

# %%
% matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Describtion of the data:
#     * State is the most viable Primary Key
#
#     * 50 states, Washington DC and the total are included:
#         - We need to decide if Washington DC should be included; we will keep it
#         - We will remove the 'All' values so it does not corrupt any calculations made
#
#     * Understand exactly what 'Rate' we are talking about along with 'Verbal' and 'Math' scores:
#         - Rate: State-wide participation in SAT
#         - Verbal: mean verbal score per State
#         - Math: mean math score per state
#
#     * Data types:
#         - State is an Object
#         - All other columns are Integers

# %%
df = pd.read_csv('sat_scores.csv')
df.dtypes
# Out:
# State     object
# Rate       int64
# Verbal     int64
# Math       int64
# dtype: object

# %%
clean_df = df[df.State != 'All'].copy()
clean_df
# Out:
#    State  Rate  Verbal  Math
# 0     CT    82     509   510
# 1     NJ    81     499   513
# 2     MA    79     511   515
# 3     NY    77     495   505
# 4     NH    72     520   516
# 5     RI    71     501   499
# 6     PA    71     500   499
# 7     VT    69     511   506
# 8     ME    69     506   500
# 9     VA    68     510   501
# 10    DE    67     501   499
# 11    MD    65     508   510
# 12    NC    65     493   499
# 13    GA    63     491   489
# 14    IN    60     499   501
# 15    SC    57     486   488
# 16    DC    56     482   474
# 17    OR    55     526   526
# 18    FL    54     498   499
# 19    WA    53     527   527
# 20    TX    53     493   499
# 21    HI    52     485   515
# 22    AK    51     514   510
# 23    CA    51     498   517
# 24    AZ    34     523   525
# 25    NV    33     509   515
# 26    CO    31     539   542
# 27    OH    26     534   439
# 28    MT    23     539   539
# 29    WV    18     527   512
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %%
list_of_states = list(clean_df.State)
list_participation_rates = list(clean_df.Rate)
list_of_list_example = zip(list_of_states, list_participation_rates)

# %%
clean_df.shape
# Out:
# (51, 4)

# %%
clean_df.State.nunique()
# Out:
# 51

# %%
clean_df.mean()
# Out:
# Rate       37.000000
# Verbal    532.529412
# Math      531.843137
# dtype: float64

# %%
clean_df.median()
# Out:
# Rate       33.0
# Verbal    527.0
# Math      525.0
# dtype: float64

# %%
clean_df.max()
# Out:
# State      WY
# Rate       82
# Verbal    593
# Math      603
# dtype: object

# %%
clean_df.min()
# Out:
# State      AK
# Rate        4
# Verbal    482
# Math      439
# dtype: object

# %% [markdown]
# ### Exploring the data through visualisation
# Below: Initial matplotlib.pyplot visualisations show evidence of a correlations between high mean scores in both verbal and math scores and low participation rates.

# %%
plt.scatter(clean_df.Verbal, clean_df.Rate)
plt.show()

# %%
plt.scatter(clean_df.Math, clean_df.Rate)
plt.show()

# %% [markdown]
# Below: The distribution of mean verbal scores is significantly tighter than that of math, yet the mean of both sets of mean scores by Sate is nearly the same. The set of mean scores for math appears to have a number of low outliers causing greater variance in the data.

# %%
plt.boxplot([clean_df.Verbal, clean_df.Math], labels=['Verbal','Math'])
plt.show()

# %%
clean_df.Verbal.var()
# Out:
# 1112.934117647059

# %%
clean_df.Math.var()
# Out:
# 1316.774901960784

# %% [markdown]
# Below: There is strong evidence of bimodal distribution within the verbal and math means. What does it 'mean'?

# %%
with seaborn.axes_style("whitegrid"):
    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    seaborn.distplot(clean_df.Verbal, ax=axes[0])
    seaborn.distplot(clean_df.Math, ax=axes[1])
fig, axes

plt.show()

# %% [markdown]
# Below: The kernel density graph below confirms that there are two distinct groups.

# %%
with seaborn.axes_style("whitegrid"):
    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    seaborn.jointplot(x="Verbal", y="Rate", kind="kde", data=clean_df, ax=axes[0])
    seaborn.jointplot(x="Math", y="Rate", kind="kde", data=clean_df, ax=axes[1])
    
fig, axes

plt.show()

# %% [markdown]
# ### Define the two distinct groups
#
# The groups are defined as having a participationg rate greater than 40 or not.

# %%
rate_greater_than_fourty = clean_df.Rate > 40
clean_df['rate_greater_than_40'] = rate_greater_than_fourty

# %%
seaborn.pairplot(data=clean_df, hue='rate_greater_than_40')
plt.show()

# %% [markdown]
# Below: States with a participation rate greater than 40 tend to have lower mean scores for both verbal and math tests. Also, thos states tend to have a tighter distribution of scores. Conversely, the distribution of scores of States under 40 is much greater. This may suggest greater homogeneity amongst States with greater participation rates.

# %%
with seaborn.axes_style("whitegrid"):
    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    seaborn.boxplot(x='rate_greater_than_40', y='Verbal', data=clean_df, ax=axes[0])
    seaborn.boxplot(x='rate_greater_than_40', y='Math', data=clean_df, ax=axes[1])
    
fig, axes

plt.show()

# %% [markdown]
# ### Pull external information into the dataset
# This will help create a robust analyse of the SAT scores and participation rate, and hopefully bring some understanding to the bimodal distribution seen above.
#
#     Investigate the impact of the following on SAT scores and participation rate:
#
#     * State population
#     * Agriculture

# %% [markdown]
# ##### Impact of State population

# %%
url = 'https://people.sc.fsu.edu/~jburkardt/datasets/census/census_2010.txt'
req = requests.get(url)

# %%
US_States = []
State_Pop = [] 

for line in req.text.split('\n'):
    if line != '':
        US_States.append((line[0:2]))
        pop = int(line[4:].replace(',','').replace(' ', '').replace('\t', '').encode('utf-8'))
        State_Pop.append(pop)
    
State_Pop_Table = zip(US_States, State_Pop)

State_Pop_DF = pd.DataFrame(data=State_Pop_Table, columns=('US_States','State_Pop'))

# %%
df_w_pop = clean_df.merge(State_Pop_DF, how='left', left_on=clean_df.State, right_on=State_Pop_DF.US_States).copy()

# %%
seaborn.pairplot(data=df_w_pop, hue='rate_greater_than_40')
plt.show()

# %% [markdown]
# Below: Population does not correlate to participation rate.

# %%
seaborn.jointplot(x='State_Pop', y='Rate', kind="kde", data=df_w_pop)
plt.show()

# %% [markdown]
# Below: This lack of correlation to population holds true even when the data is subset into groups greater and less than 40% participation.

# %%
seaborn.lmplot(x='State_Pop', y='Rate', data=df_w_pop, hue='rate_greater_than_40')
plt.show()

# %%
seaborn.lmplot(x="State_Pop", y="Rate", data=df_w_pop, lowess=True, hue="rate_greater_than_40")
plt.show()

# %% [markdown]
# Below: There is, however, less variation of population size amongs state with a participation rate below 40.

# %%
seaborn.boxplot(x='rate_greater_than_40', y='State_Pop', data=df_w_pop)
plt.show()

# %% [markdown]
# Below: Correlation between between population and math and/or verbal scores is also not significant.

# %%
with seaborn.axes_style("whitegrid"):
    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    seaborn.jointplot(x="State_Pop", y="Verbal", kind="kde", data=df_w_pop, ax=axes[0])
    seaborn.jointplot(x="State_Pop", y="Math", kind="kde", data=df_w_pop, ax=axes[1])
    
fig, axes

plt.show()

# %% [markdown]
# ##### Impact of agriculture

# %%
ag_data = pd.read_excel('FSA_Crop_National_Data_2011-15.xlsx')

# %%
df_w_ag = df_w_pop.merge(ag_data, how='left', on='State')

# %%
df_w_ag['Planted_Acres_per_Capita'] = df_w_ag.Planted_Acres_y / df_w_ag.State_Pop

# %%
seaborn.pairplot(data=df_w_ag, hue='rate_greater_than_40')
plt.show()

# %% [markdown]
# Below: The figure below clearly illustrates that States with high participation rates do not have high amounts of agriculture per capita (i.e. agriculture probably does not play a huge role in the economy).
#
# Conversely, many States with low participation rates appear to have high amounts of agriculture per capita; this should be tempered by the fact that the distribution of agriculture per capita amongs low-participation states may mean agriculture does not always effect participation rate.

# %%
seaborn.boxplot(y='Planted_Acres_per_Capita', x='rate_greater_than_40', data=df_w_ag)
plt.show()

# %% [markdown]
# ##### Deeper analysis of low participation rate States.

# %%
low_rate_states = pd.DataFrame(df_w_ag[df_w_ag.rate_greater_than_40 == False])

# %%
seaborn.pairplot(data=low_rate_states)
plt.show()

# %% [markdown]
# Below: Note the cluster of states with low participation rate and low levels of agriculture. This does not support the idea that agriculture plays a significant role in high or low participation rates.

# %%
seaborn.lmplot(x="Planted_Acres_per_Capita", y="Rate", data=low_rate_states, lowess=True)
plt.show()

# %%
seaborn.jointplot(x="Planted_Acres_per_Capita", y="Rate", data=low_rate_states, kind='kde')
plt.show()

# %%
seaborn.jointplot(x="State_Pop", y="Rate", data=low_rate_states, kind='kde')
plt.show()

# %% [markdown]
# ### Map visualisations
#
# It is clear that agriculture may play a role in participation rates. It is clear that it does not play a role in higher participation rates, but the shape of agriculture's role in States with lower rates is unclear.
#
# At this point we feel it would be appropriate to visualise this dataset on a map of the United Sates. We will does this using Tableau. This may help catalyse ideas for what drives participation rates in high-rate States, and what role agriculture and other factors may play in low-rate States.
#
# See the Tableau dashboard visualisation here:
# https://public.tableau.com/profile/publish/DSI1_Project1_Byron_Allen/DSI1_Project1#!/publish-confirm

# %%
df_w_ag.to_csv(path_or_buf='df_w_ag.csv')

# %%
df_w_ag
# Out:
#    State  Rate  Verbal  Math rate_greater_than_40 US_States  State_Pop  \
# 0     CT    82     509   510                 True        CT    3574097
# 1     NJ    81     499   513                 True        NJ    8791894
# 2     MA    79     511   515                 True        MA    6547629
# 3     NY    77     495   505                 True        NY   19378102
# 4     NH    72     520   516                 True        NH    1316470
# 5     RI    71     501   499                 True        RI    1052567
# 6     PA    71     500   499                 True        PA   12702379
# 7     VT    69     511   506                 True        VT     625741
# 8     ME    69     506   500                 True        ME    1328361
# 9     VA    68     510   501                 True        VA    8001024
# 10    DE    67     501   499                 True        DE     897934
# 11    MD    65     508   510                 True        MD    5773552
# 12    NC    65     493   499                 True        NC    9535483
# 13    GA    63     491   489                 True        GA    9687653
# 14    IN    60     499   501                 True        IN    6483802
# 15    SC    57     486   488                 True        SC    4625364
# 16    DC    56     482   474                 True        DC     601723
# 17    OR    55     526   526                 True        OR    3831074
# 18    FL    54     498   499                 True        FL   18801310
# 19    WA    53     527   527                 True        WA    6724540
# 20    TX    53     493   499                 True        TX   25145561
# 21    HI    52     485   515                 True        HI    1360301
# 22    AK    51     514   510                 True        AK     710231
# 23    CA    51     498   517                 True        CA   37253956
# 24    AZ    34     523   525                False        AZ    6392017
# 25    NV    33     509   515                False        NV    2700551
# 26    CO    31     539   542                False        CO    5029196
# 27    OH    26     534   439                False        OH   11536504
# 28    MT    23     539   539                False        MT     989415
# 29    WV    18     527   512                False        WV    1852994
# 30    ID    17     543   542                False        ID    1567582
# 31    TN    13     562   553                False        TN    6346165
# 32    NM    13     551   542                False        NM    2059179
# 33    IL    12     576   589                False        IL   12830632
# 34    KY    12     550   550                False        KY    4339367
# 35    WY    11     547   545                False        WY     563626
# 36    MI    11     561   572                False        MI    9883640
# 37    MN     9     580   589                False        MN    5303925
# 38    KS     9     577   580                False        KS    2853118
# 39    AL     9     559   554                False        AL    4779736
# 40    NE     8     562   568                False        NE    1826341
# 41    OK     8     567   561                False        OK    3751351
# 42    MO     8     577   577                False        MO    5988144
# 43    LA     7     564   562                False        LA    4533372
# 44    WI     6     584   596                False        WI    5686986
# 45    AR     6     562   550                False        AR    2915918
# 46    UT     5     575   570                False        UT    2763885
# 47    IA     5     593   603                False        IA    3046355
# 48    SD     4     577   582                False        SD     814180
